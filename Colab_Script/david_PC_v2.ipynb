# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahendra2409/PyBlender/blob/main/Colab_Script/david_PC_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# <a href="https://drive.google.com/drive/folders/1sj-RqD5HRypGx-ZLqXpvyzY1CN84qJu-?usp=drive_link" target="_parent"><img src="https://img.shields.io/badge/PyBlender_Render_Farm-blue?logo=googledrive&logoColor=white" alt="PyBlender_Render_Farm"/></a>

# %%
#@title Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title 1.Install Dependencies
# 1. Download & extract (quiet)
# !wget -nc -q https://download.blender.org/release/Blender4.0/blender-4.0.2-linux-x64.tar.xz
# !tar -xf blender-4.0.2-linux-x64.tar.xz

# 2. Setup pip silently
# !./blender-4.0.2-linux-x64/4.0/python/bin/python3.10 -m ensurepip --upgrade > /dev/null 2>&1

# 3. Install dependencies silently
# !./blender-4.0.2-linux-x64/4.0/python/bin/python3.10 -m pip install \
    scipy matplotlib numpy blendertoolbox \
    -q --no-input --disable-pip-version-check
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 12.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 102.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 15.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 45.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 33.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 116.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 94.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 14.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 13.7 MB/s eta 0:00:00

# %%
# @title
# 3. Download BlenderToolbox
# !git clone https://github.com/HTDerekLiu/BlenderToolbox.git
# Move the actual toolbox folder into your main /content/ directory so your script can 'see' it

# !mv BlenderToolbox/blendertoolbox /content/
# !./blender-4.0.2-linux-x64/4.0/python/bin/python3.10 -m pip install blendertoolbox
# Out:
# Cloning into 'BlenderToolbox'...
# remote: Enumerating objects: 2643, done.
# remote: Counting objects: 100% (452/452), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 2643 (delta 423), reused 393 (delta 393), pack-reused 2191 (from 4)
# Receiving objects: 100% (2643/2643), 222.67 MiB | 29.99 MiB/s, done.
# Resolving deltas: 100% (1581/1581), done.
# Requirement already satisfied: blendertoolbox in ./blender-4.0.2-linux-x64/4.0/python/lib/python3.10/site-packages (0.0.9)

# %% [markdown]
# ## Important Configuration Settings Checklist
#
# These are the key settings that control the rendering process:
#
# ### Paths
# - `DRIVE_BASE_PATH`: The base path in Google Drive where your PyBlender render farm data is stored. Example: `/content/drive/MyDrive/PyBlender_Render_Farm`
# - `PC_TYPE`: The specific type or category of point cloud data being rendered. This defines a subfolder within `DRIVE_BASE_PATH`. Example: `ccylinder_scaled_PC_new`
# - `GT_FILENAME`: The filename of the ground truth point cloud (`.xyz`) within the `PC_TYPE` folder. Example: `gt_ccylinder.xyz`
# - `COLORMAP`: The Matplotlib colormap to use for rendering point cloud distances. Example: `viridis`
# - `LOCAL_COLAB_BASE`: The local directory in Colab used for temporary storage of point cloud data copied from Drive. Example: `/content/local_data`
#
# ### Point Cloud Settings
# - `PT_SIZE`: The size of each point in the rendered point cloud, often interpreted as a radius if the points are rendered as spheres. Example: `0.009` (for a radius of 0.009 units)
# - `PT_COLOR`: A RGBA tuple defining the default color of the points, if not overridden by colormaps. Example: `[0.5, 1.0, 1.0, 0.0, 0.0]` (note: BlenderToolbox often uses a specific format, ensure it matches expectations).
#
# ### Object Transforms
# - `OBJ_LOCATION`: A 3-tuple representing the X, Y, Z coordinates for the object's position in Blender space. Example: `(-0.370186, -5.31554, -2.55748)`
# - `OBJ_ROTATION`: A 3-tuple representing the X, Y, Z rotation angles (in degrees) of the object. Example: `(448.706, -0.984887, -94.562)`
# - `OBJ_SCALE`: A 3-tuple representing the X, Y, Z scaling factors applied to the object. Example: `(3.71272, 3.71272, 3.71272)`

# %% [markdown]
# ## Interactive Configuration Form
#
# Use the form fields below to easily adjust the key rendering parameters. Once you've made your changes, run this cell to update the `CONFIG` dictionary in `config.py`.

# %%
#@title 2.1a Set Configuration Here
# %%writefile config.py

# ==========================================
# 1. MAIN CONFIGURATION
# ==========================================

CONFIG = {
    # --- Output Controls ---
    "SAVE_BLEND_FILE": False,   # Set to True to save the .blend scene file alongside the image
    "FORCE_OVERWRITE": True,   # Set to True to re-render even if the output image already exists

    # --- Paths ---
    "DRIVE_BASE_PATH": "/content/drive/MyDrive/PyBlender_Render_Farm",
    "PC_TYPE": "david_PC_v2",
    "GT_FILENAME": "david.xyz",
    "COLORMAP": "inferno",

    "LOCAL_COLAB_BASE": "/content/local_data",

    # --- Point Cloud Settings ---
    "PT_SIZE": 1,
    "PT_COLOR": [0.5, 1.0, 1.0, 0.0, 0.0],

    # --- Object Transforms ---
    "OBJ_LOCATION": (6.15212, -8.1798, -1.15163),
    "OBJ_ROTATION": (92.8616, -6.26444, 50.2207),
    "OBJ_SCALE": (0.013583, 0.013583, 0.013583),

    # --- Blender Render Settings ---
    "IMG_RES_X": 1000,
    "IMG_RES_Y": 1000,
    "NUM_SAMPLES": 100,
    "EXPOSURE": 1.5,

    # --- Camera Settings ---
    "CAM_LOCATION": (3, 0, 2),
    "LOOK_AT": (0, 0, 0.5),
    "FOCAL_LENGTH": 45,

    # --- Light Settings ---
    "LIGHT_ANGLE": (6, -30, -155),
    "LIGHT_STRENGTH": 2,
    "SHADOW_SOFTNESS": 0.3,
    "AMBIENT_COLOR": (0.1, 0.1, 0.1, 1),
    "SHADOW_THRESHOLD": 0.05
}

# ==========================================
# 2. GROUND TRUTH OVERRIDES
# ==========================================
GT_OVERRIDES = {
    # Example: Uncomment to apply only to GT
    # "PT_SIZE": 0.012,
}
# Out:
# Writing config.py

# %%
#@title 2.1b Core Rendering Logic
# %%writefile render.py

import os
import sys
import shutil
import numpy as np
from scipy.spatial import cKDTree

# ---> THE FIX: Tell Blender where to look for config.py <---
if '/content' not in sys.path:
    sys.path.append('/content')
from config import CONFIG, GT_OVERRIDES

# --- THE FIX FOR COLAB/MATPLOTLIB ---
os.environ['MPLBACKEND'] = 'Agg'
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
# ------------------------------------

import bpy
import blendertoolbox as bt





# ==========================================
# 3. DERIVED PATHS
# ==========================================
DRIVE_SOURCE_DIR = os.path.join(CONFIG["DRIVE_BASE_PATH"], "PointCloud", "xyzFormat", CONFIG["PC_TYPE"])
DRIVE_OUTPUT_DIR = os.path.join(CONFIG["DRIVE_BASE_PATH"], "RenderImages", CONFIG["PC_TYPE"], f"{CONFIG['COLORMAP']}_colormap")

LOCAL_SOURCE_DIR = os.path.join(CONFIG["LOCAL_COLAB_BASE"], CONFIG["PC_TYPE"])
LOCAL_GROUND_TRUTH_PATH = os.path.join(LOCAL_SOURCE_DIR, CONFIG["GT_FILENAME"])


# ==========================================
# 4. PIPELINE FUNCTIONS
# ==========================================
def setup_colab_environment():
    print("--- Setting up Environment ---")
    os.makedirs(DRIVE_OUTPUT_DIR, exist_ok=True)

    if os.path.exists(LOCAL_SOURCE_DIR):
        shutil.rmtree(LOCAL_SOURCE_DIR)

    print(f"Copying point clouds from Drive to Local Colab Storage...")
    shutil.copytree(DRIVE_SOURCE_DIR, LOCAL_SOURCE_DIR)
    print("Copy complete!\n")


def render_point_clouds():
    print("--- Starting Render Process ---")

    ground_truth_points = np.loadtxt(LOCAL_GROUND_TRUTH_PATH)
    tree = cKDTree(ground_truth_points)

    for filename in os.listdir(LOCAL_SOURCE_DIR):
        if not filename.endswith(".xyz"):
            continue

        # 1. Determine if this specific file is the Ground Truth
        is_gt = (filename == CONFIG["GT_FILENAME"])

        # 2. Create the Active Config
        active_cfg = CONFIG.copy()
        if is_gt:
            active_cfg.update(GT_OVERRIDES)

        # 3. Output checking (UPDATED WITH FORCE_OVERWRITE FLAG)
        render_output = os.path.join(DRIVE_OUTPUT_DIR, f"{os.path.splitext(filename)[0]}.png")
        if os.path.exists(render_output) and not active_cfg["FORCE_OVERWRITE"]:
            print(f"Output already exists: {filename}. Skipping...")
            continue

        print(f"Processing: {filename} {'(GROUND TRUTH MODE)' if is_gt else ''}")

        # 4. Initialize Blender
        bt.blenderInit(
            active_cfg["IMG_RES_X"],
            active_cfg["IMG_RES_Y"],
            active_cfg["NUM_SAMPLES"],
            active_cfg["EXPOSURE"]
        )

        # 5. Load Points
        current_points = ground_truth_points if is_gt else np.loadtxt(os.path.join(LOCAL_SOURCE_DIR, filename))

        # 6. Apply Color Logic
        if is_gt:
            colormap = plt.get_cmap(active_cfg["COLORMAP"])
            min_color = colormap(0.0)[:3]
            colors = np.tile(min_color, (current_points.shape[0], 1))
        else:
            distances, _ = tree.query(current_points)
            max_distance = np.percentile(distances, 99)
            normalized_distances = np.clip(distances / max_distance, 0, 1)
            normalized_distances = np.log1p(normalized_distances) / np.log1p(1)
            colormap = plt.get_cmap(active_cfg["COLORMAP"])
            colors = colormap(normalized_distances)[:, :3]

        # 7. Setup Mesh and Materials
        mesh = bt.readNumpyPoints(
            current_points,
            active_cfg["OBJ_LOCATION"],
            active_cfg["OBJ_ROTATION"],
            active_cfg["OBJ_SCALE"]
        )
        mesh = bt.setPointColors(mesh, colors)

        ptColor = bt.colorObj(active_cfg["PT_COLOR"], 0.5, 1.0, 1.0, 0.0, 0.0)
        bt.setMat_pointCloudColored(mesh, ptColor, active_cfg["PT_SIZE"])

        # 8. Setup Environment
        cam = bt.setCamera(active_cfg["CAM_LOCATION"], active_cfg["LOOK_AT"], active_cfg["FOCAL_LENGTH"])
        sun = bt.setLight_sun(active_cfg["LIGHT_ANGLE"], active_cfg["LIGHT_STRENGTH"], active_cfg["SHADOW_SOFTNESS"])
        bt.setLight_ambient(color=active_cfg["AMBIENT_COLOR"])
        bt.shadowThreshold(alphaThreshold=active_cfg["SHADOW_THRESHOLD"], interpolationMode='CARDINAL')

        bpy.context.scene.use_nodes = True
        tree_nodes = bpy.context.scene.node_tree
        tree_nodes.nodes.clear()

        render_layers = tree_nodes.nodes.new('CompositorNodeRLayers')
        denoise_node = tree_nodes.nodes.new(type='CompositorNodeDenoise')
        composite = tree_nodes.nodes.new('CompositorNodeComposite')
        viewer = tree_nodes.nodes.new('CompositorNodeViewer')

        render_layers.location = (-300, 0)
        denoise_node.location = (0, 0)
        composite.location = (300, 0)
        viewer.location = (300, -200)

        tree_nodes.links.new(render_layers.outputs['Image'], denoise_node.inputs['Image'])
        tree_nodes.links.new(denoise_node.outputs['Image'], composite.inputs['Image'])
        tree_nodes.links.new(denoise_node.outputs['Image'], viewer.inputs['Image'])

        # 9. Save Colormap Gradient
        colormap_path = os.path.join(DRIVE_OUTPUT_DIR, f"{active_cfg['COLORMAP']}_colormap.png")
        if not os.path.exists(colormap_path):
            gradient = np.linspace(0, 1, 256).reshape(1, -1)
            gradient = np.vstack([gradient] * 50)
            plt.figure(figsize=(6, 1))
            plt.imshow(gradient, aspect="auto", cmap=active_cfg["COLORMAP"])
            plt.axis("off")
            plt.savefig(colormap_path, bbox_inches="tight", pad_inches=0, dpi=300)
            plt.close()
            print(f"Colormap saved at {colormap_path}")

        # 10. Save Blend File (UPDATED LOGIC)
        if active_cfg["SAVE_BLEND_FILE"]:
            blend_file_name = f"{os.path.splitext(filename)[0]}.blend"
            blend_file_path = os.path.join(DRIVE_OUTPUT_DIR, blend_file_name)
            bpy.ops.wm.save_mainfile(filepath=blend_file_path)
            print(f"Blend file saved at {blend_file_path}")

        # 11. Render
        bt.renderImage(render_output, cam)
        print(f"Render complete for {filename}\n")


if __name__ == "__main__":
    setup_colab_environment()
    render_point_clouds()
# Out:
# Writing render.py

# %%
#@title 2.3 Start Rendering Render

# !./blender-4.0.2-linux-x64/blender -b -P render.py
# Out:
# Blender 4.0.2 (hash 9be62e85b727 built 2023-12-05 08:48:50)
# --- Setting up Environment ---
# Copying point clouds from Drive to Local Colab Storage...
# Copy complete!
#
# --- Starting Render Process ---
# Processing: denoised_david_iterpfn.xyz
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caae88>
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caaf98>
# Fra:1 Mem:15.43M (Peak 15.43M) | Time:00:00.79 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | numpy point cloud object
# Fra:1 Mem:18.59M (Peak 18.59M) | Time:00:00.79 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:18.12M (Peak 18.59M) | Time:00:00.79 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:18.12M (Peak 18.59M) | Time:00:00.79 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:18.12M (Peak 38.69M) | Time:00:03.68 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:18.12M (Peak 38.69M) | Time:00:03.68 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:03.68 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:03.68 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:03.68 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:03.68 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:03.68 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:03.68 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:03.68 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:03.68 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:03.68 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:03.68 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:03.68 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:03.68 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:03.68 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building BVH
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:03.68 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:03.68 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building BVH
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:03.68 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:03.69 | Mem:1.97M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:03.69 | Mem:1.97M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:03.69 | Mem:1.97M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:03.69 | Mem:1.97M, Peak:7.62M | Scene, ViewLayer | Updating Mesh | Copying Point clouds to device
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:03.69 | Mem:2.95M, Peak:7.62M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:03.69 | Mem:2.95M, Peak:7.62M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:03.69 | Mem:2.95M, Peak:7.62M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:03.69 | Mem:2.95M, Peak:7.62M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:03.69 | Mem:2.95M, Peak:7.62M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:03.69 | Mem:3.04M, Peak:7.62M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:03.69 | Mem:3.04M, Peak:7.62M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:03.69 | Mem:3.04M, Peak:7.62M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:03.69 | Mem:3.04M, Peak:7.62M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:03.69 | Mem:4.04M, Peak:7.62M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:03.69 | Mem:3.96M, Peak:7.62M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:03.69 | Mem:4.04M, Peak:7.62M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:03.69 | Mem:4.04M, Peak:7.62M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:24.99M (Peak 38.69M) | Time:00:03.70 | Mem:332.04M, Peak:332.04M | Scene, ViewLayer | Sample 0/100
# Fra:1 Mem:59.33M (Peak 59.33M) | Time:00:03.72 | Remaining:00:02.38 | Mem:366.37M, Peak:366.37M | Scene, ViewLayer | Sample 1/100
# Fra:1 Mem:59.34M (Peak 59.34M) | Time:00:04.70 | Remaining:00:00.25 | Mem:366.38M, Peak:366.38M | Scene, ViewLayer | Sample 80/100
# Fra:1 Mem:59.34M (Peak 59.34M) | Time:00:04.82 | Remaining:00:00.04 | Mem:366.38M, Peak:366.38M | Scene, ViewLayer | Sample 96/100
# Fra:1 Mem:74.60M (Peak 105.11M) | Time:00:04.91 | Mem:366.38M, Peak:366.38M | Scene, ViewLayer | Sample 100/100
# Fra:1 Mem:74.60M (Peak 105.11M) | Time:00:04.91 | Mem:366.38M, Peak:366.38M | Scene, ViewLayer | Finished
# Fra:1 Mem:30.22M (Peak 105.11M) | Time:00:05.03 | Compositing
# Fra:1 Mem:30.22M (Peak 105.11M) | Time:00:05.03 | Compositing | Determining resolution
# Fra:1 Mem:30.22M (Peak 105.11M) | Time:00:05.03 | Compositing | Initializing execution
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.65 | Compositing | Tile 1-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.66 | Compositing | Tile 2-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.66 | Compositing | Tile 3-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.66 | Compositing | Tile 4-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.66 | Compositing | Tile 5-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.66 | Compositing | Tile 6-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.66 | Compositing | Tile 7-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.66 | Compositing | Tile 8-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.67 | Compositing | Tile 9-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.67 | Compositing | Tile 10-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.67 | Compositing | Tile 11-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.67 | Compositing | Tile 12-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.67 | Compositing | Tile 13-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.67 | Compositing | Tile 14-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.67 | Compositing | Tile 15-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:21.68 | Compositing | Tile 16-16
# Fra:1 Mem:171.37M (Peak 171.44M) | Time:00:21.68 | Compositing | De-initializing execution
# Saved: '/content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/david_PC_v2/inferno_colormap/denoised_david_iterpfn.png'
# Time: 00:22.68 (Saving: 00:00.99)
#
# Render complete for denoised_david_iterpfn.xyz
#
# Processing: AD_david_noisy.xyz
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caae88>
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caaf98>
# Fra:1 Mem:15.43M (Peak 15.43M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | numpy point cloud object
# Fra:1 Mem:18.59M (Peak 18.59M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:18.12M (Peak 18.59M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:18.12M (Peak 18.59M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:18.12M (Peak 38.69M) | Time:00:00.36 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:18.12M (Peak 38.69M) | Time:00:00.36 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.36 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.36 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.36 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.36 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.36 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.36 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.36 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.36 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.36 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.36 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.36 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.36 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.36 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building BVH
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.36 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building OptiX acceleration structure
# Fra:1 Mem:20.18M (Peak 38.69M) | Time:00:00.36 | Mem:7.62M, Peak:7.62M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building BVH
# Fra:1 Mem:20.18M (Peak 38.69M) | Time:00:00.36 | Mem:7.62M, Peak:7.62M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.36 | Mem:1.94M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.36 | Mem:1.94M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.36 | Mem:1.94M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.36 | Mem:1.94M, Peak:7.62M | Scene, ViewLayer | Updating Mesh | Copying Point clouds to device
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.37 | Mem:2.93M, Peak:7.62M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.37 | Mem:2.93M, Peak:7.62M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.37 | Mem:2.93M, Peak:7.62M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.37 | Mem:2.93M, Peak:7.62M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.37 | Mem:2.93M, Peak:7.62M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.37 | Mem:3.01M, Peak:7.62M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.37 | Mem:3.01M, Peak:7.62M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.37 | Mem:3.01M, Peak:7.62M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.37 | Mem:3.01M, Peak:7.62M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.37 | Mem:4.01M, Peak:7.62M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.37 | Mem:3.93M, Peak:7.62M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.37 | Mem:4.02M, Peak:7.62M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.37 | Mem:4.02M, Peak:7.62M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:24.99M (Peak 38.69M) | Time:00:00.37 | Mem:332.02M, Peak:332.02M | Scene, ViewLayer | Sample 0/100
# Fra:1 Mem:59.33M (Peak 59.33M) | Time:00:00.40 | Remaining:00:02.08 | Mem:366.35M, Peak:366.35M | Scene, ViewLayer | Sample 1/100
# Fra:1 Mem:59.33M (Peak 59.33M) | Time:00:01.39 | Remaining:00:00.25 | Mem:366.36M, Peak:366.36M | Scene, ViewLayer | Sample 80/100
# Fra:1 Mem:59.33M (Peak 59.33M) | Time:00:01.51 | Remaining:00:00.04 | Mem:366.36M, Peak:366.36M | Scene, ViewLayer | Sample 96/100
# Fra:1 Mem:74.60M (Peak 105.11M) | Time:00:01.60 | Mem:366.36M, Peak:366.36M | Scene, ViewLayer | Sample 100/100
# Fra:1 Mem:74.60M (Peak 105.11M) | Time:00:01.60 | Mem:366.36M, Peak:366.36M | Scene, ViewLayer | Finished
# Fra:1 Mem:30.22M (Peak 105.11M) | Time:00:01.71 | Compositing
# Fra:1 Mem:30.22M (Peak 105.11M) | Time:00:01.71 | Compositing | Determining resolution
# Fra:1 Mem:30.22M (Peak 105.11M) | Time:00:01.71 | Compositing | Initializing execution
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.53 | Compositing | Tile 2-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.53 | Compositing | Tile 1-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.53 | Compositing | Tile 3-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.53 | Compositing | Tile 4-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.54 | Compositing | Tile 5-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.54 | Compositing | Tile 6-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.54 | Compositing | Tile 7-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.54 | Compositing | Tile 8-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.54 | Compositing | Tile 9-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.54 | Compositing | Tile 10-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.54 | Compositing | Tile 11-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.54 | Compositing | Tile 12-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.55 | Compositing | Tile 13-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.55 | Compositing | Tile 14-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.55 | Compositing | Tile 15-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:17.55 | Compositing | Tile 16-16
# Fra:1 Mem:171.37M (Peak 171.44M) | Time:00:17.55 | Compositing | De-initializing execution
# Saved: '/content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/david_PC_v2/inferno_colormap/AD_david_noisy.png'
# Time: 00:18.43 (Saving: 00:00.87)
#
# Render complete for AD_david_noisy.xyz
#
# Processing: david.xyz (GROUND TRUTH MODE)
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caae88>
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caaf98>
# Fra:1 Mem:15.43M (Peak 15.43M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | numpy point cloud object
# Fra:1 Mem:18.59M (Peak 18.59M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:18.12M (Peak 18.59M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:18.12M (Peak 18.59M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:18.12M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:18.12M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.35 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.35 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.35 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.35 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.35 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.35 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.35 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.35 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.35 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.35 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.35 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building BVH
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building BVH
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:1.96M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:1.96M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:1.97M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:1.97M, Peak:7.62M | Scene, ViewLayer | Updating Mesh | Copying Point clouds to device
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:2.95M, Peak:7.62M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:2.95M, Peak:7.62M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:2.95M, Peak:7.62M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:2.95M, Peak:7.62M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:2.95M, Peak:7.62M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.03M, Peak:7.62M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.03M, Peak:7.62M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.03M, Peak:7.62M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.04M, Peak:7.62M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.35 | Mem:4.04M, Peak:7.62M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.95M, Peak:7.62M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.35 | Mem:4.04M, Peak:7.62M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.35 | Mem:4.04M, Peak:7.62M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:24.99M (Peak 38.69M) | Time:00:00.36 | Mem:332.04M, Peak:332.04M | Scene, ViewLayer | Sample 0/100
# Fra:1 Mem:59.33M (Peak 59.33M) | Time:00:00.38 | Remaining:00:01.84 | Mem:366.37M, Peak:366.37M | Scene, ViewLayer | Sample 1/100
# Fra:1 Mem:59.34M (Peak 59.34M) | Time:00:01.25 | Remaining:00:00.22 | Mem:366.38M, Peak:366.38M | Scene, ViewLayer | Sample 80/100
# Fra:1 Mem:59.34M (Peak 59.34M) | Time:00:01.26 | Remaining:00:00.03 | Mem:366.38M, Peak:366.38M | Scene, ViewLayer | Sample 96/100
# Fra:1 Mem:74.60M (Peak 105.12M) | Time:00:01.32 | Mem:366.38M, Peak:366.38M | Scene, ViewLayer | Sample 100/100
# Fra:1 Mem:74.60M (Peak 105.12M) | Time:00:01.32 | Mem:366.38M, Peak:366.38M | Scene, ViewLayer | Finished
# Fra:1 Mem:30.22M (Peak 105.12M) | Time:00:01.43 | Compositing
# Fra:1 Mem:30.22M (Peak 105.12M) | Time:00:01.43 | Compositing | Determining resolution
# Fra:1 Mem:30.22M (Peak 105.12M) | Time:00:01.43 | Compositing | Initializing execution
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.51 | Compositing | Tile 1-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.51 | Compositing | Tile 2-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.51 | Compositing | Tile 3-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.51 | Compositing | Tile 4-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.52 | Compositing | Tile 5-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.52 | Compositing | Tile 6-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.52 | Compositing | Tile 7-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.53 | Compositing | Tile 8-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.53 | Compositing | Tile 9-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.53 | Compositing | Tile 10-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.53 | Compositing | Tile 11-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.53 | Compositing | Tile 12-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.54 | Compositing | Tile 13-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.54 | Compositing | Tile 14-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.54 | Compositing | Tile 15-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.54 | Compositing | Tile 16-16
# Fra:1 Mem:171.37M (Peak 171.44M) | Time:00:15.54 | Compositing | De-initializing execution
# Saved: '/content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/david_PC_v2/inferno_colormap/david.png'
# Time: 00:16.55 (Saving: 00:00.99)
#
# Render complete for david.xyz
#
# Processing: ours_denoised_david_noisy.xyz
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caae88>
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caaf98>
# Fra:1 Mem:15.39M (Peak 15.39M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | numpy point cloud object
# Fra:1 Mem:18.50M (Peak 18.50M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:18.04M (Peak 18.50M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:18.04M (Peak 18.50M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:18.04M (Peak 38.61M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:18.04M (Peak 38.61M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:18.12M (Peak 38.61M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:18.12M (Peak 38.61M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:18.12M (Peak 38.61M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:18.12M (Peak 38.61M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:18.12M (Peak 38.61M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:18.12M (Peak 38.61M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:18.12M (Peak 38.61M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:18.12M (Peak 38.61M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:18.12M (Peak 38.61M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:18.12M (Peak 38.61M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:18.12M (Peak 38.61M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:18.90M (Peak 38.61M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:18.90M (Peak 38.61M) | Time:00:00.34 | Mem:0.79M, Peak:0.79M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building BVH
# Fra:1 Mem:18.90M (Peak 38.61M) | Time:00:00.34 | Mem:0.79M, Peak:0.79M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building OptiX acceleration structure
# Fra:1 Mem:20.07M (Peak 38.61M) | Time:00:00.34 | Mem:1.96M, Peak:1.96M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building BVH
# Fra:1 Mem:20.07M (Peak 38.61M) | Time:00:00.34 | Mem:1.96M, Peak:1.96M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building OptiX acceleration structure
# Fra:1 Mem:18.90M (Peak 38.61M) | Time:00:00.34 | Mem:1.91M, Peak:7.51M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:18.90M (Peak 38.61M) | Time:00:00.34 | Mem:1.91M, Peak:7.51M | Scene, ViewLayer | Updating Scene BVH | Building OptiX acceleration structure
# Fra:1 Mem:18.90M (Peak 38.61M) | Time:00:00.34 | Mem:1.91M, Peak:7.51M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:18.90M (Peak 38.61M) | Time:00:00.34 | Mem:1.91M, Peak:7.51M | Scene, ViewLayer | Updating Mesh | Copying Point clouds to device
# Fra:1 Mem:19.87M (Peak 38.61M) | Time:00:00.35 | Mem:2.89M, Peak:7.51M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:19.87M (Peak 38.61M) | Time:00:00.35 | Mem:2.89M, Peak:7.51M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:19.87M (Peak 38.61M) | Time:00:00.35 | Mem:2.89M, Peak:7.51M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:19.87M (Peak 38.61M) | Time:00:00.35 | Mem:2.89M, Peak:7.51M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:19.87M (Peak 38.61M) | Time:00:00.35 | Mem:2.89M, Peak:7.51M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:19.87M (Peak 38.61M) | Time:00:00.35 | Mem:2.97M, Peak:7.51M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:19.87M (Peak 38.61M) | Time:00:00.35 | Mem:2.97M, Peak:7.51M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:1 Mem:19.87M (Peak 38.61M) | Time:00:00.35 | Mem:2.97M, Peak:7.51M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:19.87M (Peak 38.61M) | Time:00:00.35 | Mem:2.97M, Peak:7.51M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:20.87M (Peak 38.61M) | Time:00:00.35 | Mem:3.97M, Peak:7.51M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:20.88M (Peak 38.61M) | Time:00:00.35 | Mem:3.89M, Peak:7.51M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:20.88M (Peak 38.61M) | Time:00:00.35 | Mem:3.97M, Peak:7.51M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:20.88M (Peak 38.61M) | Time:00:00.35 | Mem:3.97M, Peak:7.51M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:24.88M (Peak 38.61M) | Time:00:00.36 | Mem:331.97M, Peak:331.97M | Scene, ViewLayer | Sample 0/100
# Fra:1 Mem:59.21M (Peak 59.21M) | Time:00:00.38 | Remaining:00:02.07 | Mem:366.30M, Peak:366.30M | Scene, ViewLayer | Sample 1/100
# Fra:1 Mem:59.22M (Peak 59.22M) | Time:00:01.31 | Remaining:00:00.23 | Mem:366.31M, Peak:366.31M | Scene, ViewLayer | Sample 80/100
# Fra:1 Mem:59.22M (Peak 59.22M) | Time:00:01.41 | Remaining:00:00.04 | Mem:366.31M, Peak:366.31M | Scene, ViewLayer | Sample 96/100
# Fra:1 Mem:74.48M (Peak 105.00M) | Time:00:01.51 | Mem:366.31M, Peak:366.31M | Scene, ViewLayer | Sample 100/100
# Fra:1 Mem:74.48M (Peak 105.00M) | Time:00:01.51 | Mem:366.31M, Peak:366.31M | Scene, ViewLayer | Finished
# Fra:1 Mem:30.18M (Peak 105.00M) | Time:00:01.62 | Compositing
# Fra:1 Mem:30.18M (Peak 105.00M) | Time:00:01.62 | Compositing | Determining resolution
# Fra:1 Mem:30.18M (Peak 105.00M) | Time:00:01.62 | Compositing | Initializing execution
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.40 | Compositing | Tile 1-16
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.41 | Compositing | Tile 2-16
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.41 | Compositing | Tile 3-16
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.42 | Compositing | Tile 4-16
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.42 | Compositing | Tile 5-16
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.42 | Compositing | Tile 6-16
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.42 | Compositing | Tile 7-16
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.43 | Compositing | Tile 8-16
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.43 | Compositing | Tile 9-16
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.43 | Compositing | Tile 10-16
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.43 | Compositing | Tile 11-16
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.43 | Compositing | Tile 12-16
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.44 | Compositing | Tile 13-16
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.44 | Compositing | Tile 15-16
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.44 | Compositing | Tile 14-16
# Fra:1 Mem:171.39M (Peak 171.39M) | Time:00:15.44 | Compositing | Tile 16-16
# Fra:1 Mem:171.33M (Peak 171.39M) | Time:00:15.44 | Compositing | De-initializing execution
# Saved: '/content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/david_PC_v2/inferno_colormap/ours_denoised_david_noisy.png'
# Time: 00:16.45 (Saving: 00:00.99)
#
# Render complete for ours_denoised_david_noisy.xyz
#
# Processing: bilateral_david_denoised.xyz
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caae88>
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caaf98>
# Fra:1 Mem:15.43M (Peak 15.43M) | Time:00:00.29 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | numpy point cloud object
# Fra:1 Mem:18.59M (Peak 18.59M) | Time:00:00.30 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:18.12M (Peak 18.59M) | Time:00:00.30 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:18.12M (Peak 18.59M) | Time:00:00.30 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:18.12M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:18.12M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.42 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.42 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building BVH
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.42 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building OptiX acceleration structure
# Fra:1 Mem:20.18M (Peak 38.69M) | Time:00:00.42 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building BVH
# Fra:1 Mem:20.18M (Peak 38.69M) | Time:00:00.42 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.42 | Mem:1.94M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.42 | Mem:1.94M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.42 | Mem:1.94M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.42 | Mem:1.94M, Peak:7.62M | Scene, ViewLayer | Updating Mesh | Copying Point clouds to device
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.42 | Mem:2.93M, Peak:7.62M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.42 | Mem:2.93M, Peak:7.62M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.42 | Mem:2.93M, Peak:7.62M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.42 | Mem:2.93M, Peak:7.62M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.42 | Mem:2.93M, Peak:7.62M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.42 | Mem:3.01M, Peak:7.62M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.42 | Mem:3.01M, Peak:7.62M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.42 | Mem:3.01M, Peak:7.62M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.42 | Mem:3.01M, Peak:7.62M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.43 | Mem:4.01M, Peak:7.62M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.43 | Mem:3.93M, Peak:7.62M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.43 | Mem:4.01M, Peak:7.62M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.43 | Mem:4.01M, Peak:7.62M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:24.99M (Peak 38.69M) | Time:00:00.43 | Mem:332.01M, Peak:332.01M | Scene, ViewLayer | Sample 0/100
# Fra:1 Mem:59.33M (Peak 59.33M) | Time:00:00.46 | Remaining:00:02.42 | Mem:366.35M, Peak:366.35M | Scene, ViewLayer | Sample 1/100
# Fra:1 Mem:59.33M (Peak 59.33M) | Time:00:01.49 | Remaining:00:00.26 | Mem:366.35M, Peak:366.35M | Scene, ViewLayer | Sample 80/100
# Fra:1 Mem:59.33M (Peak 59.33M) | Time:00:01.61 | Remaining:00:00.04 | Mem:366.35M, Peak:366.35M | Scene, ViewLayer | Sample 96/100
# Fra:1 Mem:74.60M (Peak 105.11M) | Time:00:01.70 | Mem:366.35M, Peak:366.35M | Scene, ViewLayer | Sample 100/100
# Fra:1 Mem:74.60M (Peak 105.11M) | Time:00:01.70 | Mem:366.35M, Peak:366.35M | Scene, ViewLayer | Finished
# Fra:1 Mem:30.22M (Peak 105.11M) | Time:00:01.81 | Compositing
# Fra:1 Mem:30.22M (Peak 105.11M) | Time:00:01.81 | Compositing | Determining resolution
# Fra:1 Mem:30.22M (Peak 105.11M) | Time:00:01.81 | Compositing | Initializing execution
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.20 | Compositing | Tile 1-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.20 | Compositing | Tile 2-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.20 | Compositing | Tile 3-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.21 | Compositing | Tile 4-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.21 | Compositing | Tile 5-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.21 | Compositing | Tile 7-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.21 | Compositing | Tile 6-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.22 | Compositing | Tile 8-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.22 | Compositing | Tile 9-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.22 | Compositing | Tile 10-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.22 | Compositing | Tile 11-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.22 | Compositing | Tile 12-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.23 | Compositing | Tile 13-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.23 | Compositing | Tile 14-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.23 | Compositing | Tile 15-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.24 | Compositing | Tile 16-16
# Fra:1 Mem:171.37M (Peak 171.44M) | Time:00:15.24 | Compositing | De-initializing execution
# Saved: '/content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/david_PC_v2/inferno_colormap/bilateral_david_denoised.png'
# Time: 00:16.23 (Saving: 00:00.98)
#
# Render complete for bilateral_david_denoised.xyz
#
# Processing: wlop_david_denoised.xyz
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caae88>
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caaf98>
# Fra:1 Mem:15.11M (Peak 15.11M) | Time:00:00.31 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | numpy point cloud object
# Fra:1 Mem:17.96M (Peak 17.96M) | Time:00:00.31 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:17.50M (Peak 17.96M) | Time:00:00.31 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:17.51M (Peak 17.96M) | Time:00:00.31 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:17.51M (Peak 38.08M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:17.51M (Peak 38.08M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:17.59M (Peak 38.08M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:17.59M (Peak 38.08M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:17.59M (Peak 38.08M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:17.59M (Peak 38.08M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:17.59M (Peak 38.08M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:17.59M (Peak 38.08M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:17.59M (Peak 38.08M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:17.59M (Peak 38.08M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:17.59M (Peak 38.08M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:17.59M (Peak 38.08M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:17.59M (Peak 38.08M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:18.30M (Peak 38.08M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:18.30M (Peak 38.08M) | Time:00:00.43 | Mem:0.72M, Peak:0.72M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building BVH
# Fra:1 Mem:18.30M (Peak 38.08M) | Time:00:00.43 | Mem:0.72M, Peak:0.72M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building OptiX acceleration structure
# Fra:1 Mem:19.37M (Peak 38.08M) | Time:00:00.43 | Mem:0.72M, Peak:0.72M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building BVH
# Fra:1 Mem:19.37M (Peak 38.08M) | Time:00:00.43 | Mem:0.72M, Peak:0.72M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building OptiX acceleration structure
# Fra:1 Mem:18.30M (Peak 38.08M) | Time:00:00.43 | Mem:1.76M, Peak:6.86M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:18.30M (Peak 38.08M) | Time:00:00.43 | Mem:1.76M, Peak:6.86M | Scene, ViewLayer | Updating Scene BVH | Building OptiX acceleration structure
# Fra:1 Mem:18.30M (Peak 38.08M) | Time:00:00.43 | Mem:1.76M, Peak:6.86M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:18.30M (Peak 38.08M) | Time:00:00.43 | Mem:1.76M, Peak:6.86M | Scene, ViewLayer | Updating Mesh | Copying Point clouds to device
# Fra:1 Mem:19.19M (Peak 38.08M) | Time:00:00.43 | Mem:2.65M, Peak:6.86M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:19.19M (Peak 38.08M) | Time:00:00.43 | Mem:2.65M, Peak:6.86M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:19.19M (Peak 38.08M) | Time:00:00.43 | Mem:2.65M, Peak:6.86M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:19.19M (Peak 38.08M) | Time:00:00.43 | Mem:2.65M, Peak:6.86M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:19.19M (Peak 38.08M) | Time:00:00.43 | Mem:2.65M, Peak:6.86M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:19.19M (Peak 38.08M) | Time:00:00.43 | Mem:2.73M, Peak:6.86M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:19.19M (Peak 38.08M) | Time:00:00.43 | Mem:2.73M, Peak:6.86M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:1 Mem:19.19M (Peak 38.08M) | Time:00:00.43 | Mem:2.73M, Peak:6.86M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:19.19M (Peak 38.08M) | Time:00:00.43 | Mem:2.73M, Peak:6.86M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:20.19M (Peak 38.08M) | Time:00:00.44 | Mem:3.73M, Peak:6.86M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:20.19M (Peak 38.08M) | Time:00:00.44 | Mem:3.65M, Peak:6.86M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:20.19M (Peak 38.08M) | Time:00:00.44 | Mem:3.73M, Peak:6.86M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:20.19M (Peak 38.08M) | Time:00:00.44 | Mem:3.73M, Peak:6.86M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:24.20M (Peak 38.08M) | Time:00:00.44 | Mem:331.73M, Peak:331.73M | Scene, ViewLayer | Sample 0/100
# Fra:1 Mem:58.53M (Peak 58.53M) | Time:00:00.47 | Remaining:00:02.28 | Mem:366.07M, Peak:366.07M | Scene, ViewLayer | Sample 1/100
# Fra:1 Mem:58.54M (Peak 58.54M) | Time:00:01.49 | Remaining:00:00.26 | Mem:366.08M, Peak:366.08M | Scene, ViewLayer | Sample 80/100
# Fra:1 Mem:58.54M (Peak 58.54M) | Time:00:01.61 | Remaining:00:00.04 | Mem:366.08M, Peak:366.08M | Scene, ViewLayer | Sample 96/100
# Fra:1 Mem:73.80M (Peak 104.32M) | Time:00:01.69 | Mem:366.08M, Peak:366.08M | Scene, ViewLayer | Sample 100/100
# Fra:1 Mem:73.80M (Peak 104.32M) | Time:00:01.69 | Mem:366.08M, Peak:366.08M | Scene, ViewLayer | Finished
# Fra:1 Mem:29.92M (Peak 104.32M) | Time:00:01.80 | Compositing
# Fra:1 Mem:29.92M (Peak 104.32M) | Time:00:01.80 | Compositing | Determining resolution
# Fra:1 Mem:29.92M (Peak 104.32M) | Time:00:01.80 | Compositing | Initializing execution
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.93 | Compositing | Tile 1-16
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.93 | Compositing | Tile 3-16
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.93 | Compositing | Tile 2-16
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.93 | Compositing | Tile 4-16
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.94 | Compositing | Tile 5-16
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.94 | Compositing | Tile 6-16
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.94 | Compositing | Tile 7-16
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.94 | Compositing | Tile 8-16
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.95 | Compositing | Tile 9-16
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.95 | Compositing | Tile 10-16
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.95 | Compositing | Tile 11-16
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.95 | Compositing | Tile 12-16
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.96 | Compositing | Tile 13-16
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.96 | Compositing | Tile 14-16
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.96 | Compositing | Tile 15-16
# Fra:1 Mem:171.14M (Peak 171.14M) | Time:00:14.96 | Compositing | Tile 16-16
# Fra:1 Mem:171.07M (Peak 171.14M) | Time:00:14.96 | Compositing | De-initializing execution
# Saved: '/content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/david_PC_v2/inferno_colormap/wlop_david_denoised.png'
# Time: 00:15.97 (Saving: 00:00.99)
#
# Render complete for wlop_david_denoised.xyz
#
# Processing: denoised_david_noisy_straightpcf.xyz
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caae88>
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caaf98>
# Fra:1 Mem:15.43M (Peak 15.43M) | Time:00:00.30 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | numpy point cloud object
# Fra:1 Mem:18.59M (Peak 18.59M) | Time:00:00.30 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:18.12M (Peak 18.59M) | Time:00:00.30 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:18.12M (Peak 18.59M) | Time:00:00.30 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:18.12M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:18.12M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.41 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Computing attributes
# ...
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.08 | Compositing | Tile 10-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.09 | Compositing | Tile 11-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.09 | Compositing | Tile 12-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.09 | Compositing | Tile 13-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.09 | Compositing | Tile 14-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.09 | Compositing | Tile 15-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.09 | Compositing | Tile 16-16
# Fra:1 Mem:171.37M (Peak 171.44M) | Time:00:15.09 | Compositing | De-initializing execution
# Saved: '/content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/david_PC_v2/inferno_colormap/david_noisy.png'
# Time: 00:15.91 (Saving: 00:00.81)
#
# Render complete for david_noisy.xyz
#
# Processing: david_p2pbridge.xyz
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caae88>
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caaf98>
# Fra:1 Mem:15.43M (Peak 15.43M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | numpy point cloud object
# Fra:1 Mem:18.59M (Peak 18.59M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:18.12M (Peak 18.59M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:18.12M (Peak 18.59M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:18.12M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:18.12M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building BVH
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building BVH
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:2.03M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:2.03M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:2.03M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:2.03M, Peak:7.62M | Scene, ViewLayer | Updating Mesh | Copying Point clouds to device
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.02M, Peak:7.62M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.02M, Peak:7.62M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.02M, Peak:7.62M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.02M, Peak:7.62M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.02M, Peak:7.62M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.10M, Peak:7.62M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.10M, Peak:7.62M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.10M, Peak:7.62M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.10M, Peak:7.62M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.35 | Mem:4.10M, Peak:7.62M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.35 | Mem:4.02M, Peak:7.62M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.35 | Mem:4.10M, Peak:7.62M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.35 | Mem:4.10M, Peak:7.62M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:24.99M (Peak 38.69M) | Time:00:00.36 | Mem:332.10M, Peak:332.10M | Scene, ViewLayer | Sample 0/100
# Fra:1 Mem:59.33M (Peak 59.33M) | Time:00:00.38 | Remaining:00:02.06 | Mem:366.44M, Peak:366.44M | Scene, ViewLayer | Sample 1/100
# Fra:1 Mem:59.34M (Peak 59.34M) | Time:00:01.37 | Remaining:00:00.25 | Mem:366.45M, Peak:366.45M | Scene, ViewLayer | Sample 80/100
# Fra:1 Mem:59.34M (Peak 59.34M) | Time:00:01.49 | Remaining:00:00.04 | Mem:366.45M, Peak:366.45M | Scene, ViewLayer | Sample 96/100
# Fra:1 Mem:74.60M (Peak 105.12M) | Time:00:01.59 | Mem:366.45M, Peak:366.45M | Scene, ViewLayer | Sample 100/100
# Fra:1 Mem:74.60M (Peak 105.12M) | Time:00:01.59 | Mem:366.45M, Peak:366.45M | Scene, ViewLayer | Finished
# Fra:1 Mem:30.22M (Peak 105.12M) | Time:00:01.72 | Compositing
# Fra:1 Mem:30.22M (Peak 105.12M) | Time:00:01.72 | Compositing | Determining resolution
# Fra:1 Mem:30.22M (Peak 105.12M) | Time:00:01.72 | Compositing | Initializing execution
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.94 | Compositing | Tile 1-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.94 | Compositing | Tile 2-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.94 | Compositing | Tile 3-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.94 | Compositing | Tile 4-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.95 | Compositing | Tile 5-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.95 | Compositing | Tile 6-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.95 | Compositing | Tile 7-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.95 | Compositing | Tile 8-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.95 | Compositing | Tile 9-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.95 | Compositing | Tile 10-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.95 | Compositing | Tile 11-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.95 | Compositing | Tile 12-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.96 | Compositing | Tile 13-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.96 | Compositing | Tile 14-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.96 | Compositing | Tile 15-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:15.96 | Compositing | Tile 16-16
# Fra:1 Mem:171.37M (Peak 171.44M) | Time:00:15.96 | Compositing | De-initializing execution
# Saved: '/content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/david_PC_v2/inferno_colormap/david_p2pbridge.png'
# Time: 00:16.83 (Saving: 00:00.86)
#
# Render complete for david_p2pbridge.xyz
#
# Processing: delnoise_40.01_david_noisy.xyz
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caae88>
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7819a9caaf98>
# Fra:1 Mem:15.43M (Peak 15.43M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | numpy point cloud object
# Fra:1 Mem:18.59M (Peak 18.59M) | Time:00:00.26 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:18.12M (Peak 18.59M) | Time:00:00.26 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:18.12M (Peak 18.59M) | Time:00:00.26 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:18.12M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:18.12M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:18.21M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.34 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building BVH
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.34 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.34 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building BVH
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.34 | Mem:0.80M, Peak:0.80M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:1.95M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:1.95M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Building OptiX acceleration structure
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:1.95M, Peak:7.62M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:19.00M (Peak 38.69M) | Time:00:00.35 | Mem:1.95M, Peak:7.62M | Scene, ViewLayer | Updating Mesh | Copying Point clouds to device
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:2.93M, Peak:7.62M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:2.93M, Peak:7.62M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:2.93M, Peak:7.62M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:2.93M, Peak:7.62M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:2.93M, Peak:7.62M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.02M, Peak:7.62M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.02M, Peak:7.62M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.02M, Peak:7.62M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:19.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.02M, Peak:7.62M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.35 | Mem:4.02M, Peak:7.62M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.35 | Mem:3.94M, Peak:7.62M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.35 | Mem:4.02M, Peak:7.62M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:20.99M (Peak 38.69M) | Time:00:00.35 | Mem:4.02M, Peak:7.62M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:24.99M (Peak 38.69M) | Time:00:00.36 | Mem:332.02M, Peak:332.02M | Scene, ViewLayer | Sample 0/100
# Fra:1 Mem:59.33M (Peak 59.33M) | Time:00:00.38 | Remaining:00:02.08 | Mem:366.35M, Peak:366.35M | Scene, ViewLayer | Sample 1/100
# Fra:1 Mem:59.34M (Peak 59.34M) | Time:00:01.34 | Remaining:00:00.24 | Mem:366.36M, Peak:366.36M | Scene, ViewLayer | Sample 80/100
# Fra:1 Mem:59.34M (Peak 59.34M) | Time:00:01.45 | Remaining:00:00.04 | Mem:366.36M, Peak:366.36M | Scene, ViewLayer | Sample 96/100
# Fra:1 Mem:74.60M (Peak 105.11M) | Time:00:01.53 | Mem:366.36M, Peak:366.36M | Scene, ViewLayer | Sample 100/100
# Fra:1 Mem:74.60M (Peak 105.11M) | Time:00:01.53 | Mem:366.36M, Peak:366.36M | Scene, ViewLayer | Finished
# Fra:1 Mem:30.22M (Peak 105.11M) | Time:00:01.64 | Compositing
# Fra:1 Mem:30.22M (Peak 105.11M) | Time:00:01.64 | Compositing | Determining resolution
# Fra:1 Mem:30.22M (Peak 105.11M) | Time:00:01.64 | Compositing | Initializing execution
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.02 | Compositing | Tile 2-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.02 | Compositing | Tile 1-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.02 | Compositing | Tile 3-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.02 | Compositing | Tile 4-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.03 | Compositing | Tile 5-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.03 | Compositing | Tile 6-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.03 | Compositing | Tile 7-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.03 | Compositing | Tile 8-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.03 | Compositing | Tile 9-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.03 | Compositing | Tile 10-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.03 | Compositing | Tile 11-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.03 | Compositing | Tile 12-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.03 | Compositing | Tile 13-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.03 | Compositing | Tile 14-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.04 | Compositing | Tile 15-16
# Fra:1 Mem:171.44M (Peak 171.44M) | Time:00:16.04 | Compositing | Tile 16-16
# Fra:1 Mem:171.37M (Peak 171.44M) | Time:00:16.04 | Compositing | De-initializing execution
# Saved: '/content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/david_PC_v2/inferno_colormap/delnoise_40.01_david_noisy.png'
# Time: 00:16.84 (Saving: 00:00.79)
#
# Render complete for delnoise_40.01_david_noisy.xyz
#
#
# Blender quit

# %%
#@title Extra: 3D PointCloud Visualizer
import numpy as np
import plotly.graph_objs as go

# 1. PATH TO YOUR POINT CLOUD
# Point this to any .xyz file you want to inspect (either on Drive or Local Colab storage)
PC_PATH = "/content/local_data/ccylinder_scaled_PC_new/AD_ccylinder_gaussian_3.5.xyz"

def view_point_cloud(filepath, max_points=100000):
    print(f"Loading {filepath}...")
    try:
        points = np.loadtxt(filepath)
    except Exception as e:
        print(f"Error loading file: {e}")
        return

    # 2. OPTIMIZATION
    # Browsers will crash if you try to render millions of points in Plotly.
    # If the point cloud is huge, we randomly sample it down to keep it interactive.
    if len(points) > max_points:
        print(f"Subsampling from {len(points)} to {max_points} points for smooth viewing...")
        indices = np.random.choice(len(points), max_points, replace=False)
        points = points[indices]

    x, y, z = points[:, 0], points[:, 1], points[:, 2]

    # Calculate center bounding box for reference
    center_x = (np.max(x) + np.min(x)) / 2
    center_y = (np.max(y) + np.min(y)) / 2
    center_z = (np.max(z) + np.min(z)) / 2
    print(f"\n--- Point Cloud Stats ---")
    print(f"X range: {np.min(x):.2f} to {np.max(x):.2f} (Center: {center_x:.2f})")
    print(f"Y range: {np.min(y):.2f} to {np.max(y):.2f} (Center: {center_y:.2f})")
    print(f"Z range: {np.min(z):.2f} to {np.max(z):.2f} (Center: {center_z:.2f})")

    # 3. BUILD THE INTERACTIVE PLOT
    print("\nGenerating interactive 3D viewer...")
    fig = go.Figure(data=[go.Scatter3d(
        x=x, y=y, z=z,
        mode='markers',
        marker=dict(
            size=1.5,
            color=z,                 # Color points by height to give depth
            colorscale='Viridis',
            opacity=0.8
        )
    )])

    # Lock the aspect ratio so the object doesn't stretch weirdly
    fig.update_layout(
        scene=dict(
            aspectmode='data',
            xaxis_title='X Axis',
            yaxis_title='Y Axis',
            zaxis_title='Z Axis'
        ),
        margin=dict(l=0, r=0, b=0, t=0),
        height=700
    )

    fig.show()

# Run the viewer
view_point_cloud(PC_PATH)
# Out:
# Loading /content/local_data/ccylinder_scaled_PC_new/AD_ccylinder_gaussian_3.5.xyz...
# Error loading file: /content/local_data/ccylinder_scaled_PC_new/AD_ccylinder_gaussian_3.5.xyz not found.
