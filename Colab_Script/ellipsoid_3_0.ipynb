# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahendra2409/PyBlender/blob/main/Colab_Script/ellipsoid_3_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# <a href="https://drive.google.com/drive/folders/1sj-RqD5HRypGx-ZLqXpvyzY1CN84qJu-?usp=drive_link" target="_parent"><img src="https://img.shields.io/badge/PyBlender_Render_Farm-blue?logo=googledrive&logoColor=white" alt="PyBlender_Render_Farm"/></a>

# %%
#@title Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title 1.Install Dependencies
# 1. Download & extract (quiet)
# !wget -nc -q https://download.blender.org/release/Blender4.0/blender-4.0.2-linux-x64.tar.xz
# !tar -xf blender-4.0.2-linux-x64.tar.xz

# 2. Setup pip silently
# !./blender-4.0.2-linux-x64/4.0/python/bin/python3.10 -m ensurepip --upgrade > /dev/null 2>&1

# 3. Install dependencies silently
# !./blender-4.0.2-linux-x64/4.0/python/bin/python3.10 -m pip install \
    scipy matplotlib numpy blendertoolbox \
    -q --no-input --disable-pip-version-check
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 12.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 104.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 16.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 112.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 30.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 96.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 126.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 19.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 15.8 MB/s eta 0:00:00

# %%
# @title
# 3. Download BlenderToolbox
# !git clone https://github.com/HTDerekLiu/BlenderToolbox.git
# Move the actual toolbox folder into your main /content/ directory so your script can 'see' it

# !mv BlenderToolbox/blendertoolbox /content/
# !./blender-4.0.2-linux-x64/4.0/python/bin/python3.10 -m pip install blendertoolbox
# Out:
# Cloning into 'BlenderToolbox'...
# remote: Enumerating objects: 2643, done.
# remote: Counting objects: 100% (453/453), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 2643 (delta 423), reused 393 (delta 393), pack-reused 2190 (from 3)
# Receiving objects: 100% (2643/2643), 222.67 MiB | 24.99 MiB/s, done.
# Resolving deltas: 100% (1583/1583), done.
# Requirement already satisfied: blendertoolbox in ./blender-4.0.2-linux-x64/4.0/python/lib/python3.10/site-packages (0.0.9)

# %% [markdown]
# ## Important Configuration Settings Checklist
#
# These are the key settings that control the rendering process:
#
# ### Paths
# - `DRIVE_BASE_PATH`: The base path in Google Drive where your PyBlender render farm data is stored. Example: `/content/drive/MyDrive/PyBlender_Render_Farm`
# - `PC_TYPE`: The specific type or category of point cloud data being rendered. This defines a subfolder within `DRIVE_BASE_PATH`. Example: `ccylinder_scaled_PC_new`
# - `GT_FILENAME`: The filename of the ground truth point cloud (`.xyz`) within the `PC_TYPE` folder. Example: `gt_ccylinder.xyz`
# - `COLORMAP`: The Matplotlib colormap to use for rendering point cloud distances. Example: `viridis`
# - `LOCAL_COLAB_BASE`: The local directory in Colab used for temporary storage of point cloud data copied from Drive. Example: `/content/local_data`
#
# ### Point Cloud Settings
# - `PT_SIZE`: The size of each point in the rendered point cloud, often interpreted as a radius if the points are rendered as spheres. Example: `0.009` (for a radius of 0.009 units)
# - `PT_COLOR`: A RGBA tuple defining the default color of the points, if not overridden by colormaps. Example: `[0.5, 1.0, 1.0, 0.0, 0.0]` (note: BlenderToolbox often uses a specific format, ensure it matches expectations).
#
# ### Object Transforms
# - `OBJ_LOCATION`: A 3-tuple representing the X, Y, Z coordinates for the object's position in Blender space. Example: `(-0.370186, -5.31554, -2.55748)`
# - `OBJ_ROTATION`: A 3-tuple representing the X, Y, Z rotation angles (in degrees) of the object. Example: `(448.706, -0.984887, -94.562)`
# - `OBJ_SCALE`: A 3-tuple representing the X, Y, Z scaling factors applied to the object. Example: `(3.71272, 3.71272, 3.71272)`

# %%
#@title 2.1a Set Configuration Here
# %%writefile config.py

# ==========================================
# 1. MAIN CONFIGURATION
# ==========================================
CONFIG = {
    # --- Output Controls ---
    "SAVE_BLEND_FILE": True,   # Set to True to save the .blend scene file alongside the image
    "FORCE_OVERWRITE": True,   # Set to True to re-render even if the output image already exists

    # --- Paths ---
    "DRIVE_BASE_PATH": "/content/drive/MyDrive/PyBlender_Render_Farm",
    "PC_TYPE": "ellipsoid_3.0_PC",
    "GT_FILENAME": "ellipsoid.xyz",
    "COLORMAP": "inferno",

    "LOCAL_COLAB_BASE": "/content/local_data",

    # --- Blender Render Settings ---
    "IMG_RES_X": 1000,
    "IMG_RES_Y": 1000,
    "NUM_SAMPLES": 100,
    "EXPOSURE": 1.5,

    # --- Point Cloud Settings ---
    "PT_SIZE": 0.007,
    "PT_COLOR": [0.5, 1.0, 1.0, 0.0, 0.0],

    # --- Object Transforms ---
    "OBJ_LOCATION": (0.007266, 0.137527, 0.187947),
    "OBJ_ROTATION": (544.23, 17.843, -319.204),
    "OBJ_SCALE": (2.0, 2.0, 2.0),

    # --- Camera Settings ---
    "CAM_LOCATION": (0.141656, 2.50472, 1.37419),
    "LOOK_AT": (0, 0, 0),
    "FOCAL_LENGTH": 45,

    # --- Light Settings ---
    "LIGHT_ANGLE": (6, -30, -155),
    "LIGHT_STRENGTH": 2,
    "SHADOW_SOFTNESS": 0.3,
    "AMBIENT_COLOR": (0.1, 0.1, 0.1, 1),
    "SHADOW_THRESHOLD": 0.05
}

# ==========================================
# 2. GROUND TRUTH OVERRIDES
# ==========================================
GT_OVERRIDES = {
    # Example: Uncomment to apply only to GT
    # "PT_SIZE": 0.012,
}
# Out:
# Overwriting config.py

# %%
#@title 2.1b Core Rendering Logic
# %%writefile render.py

import os
import sys
import shutil
import numpy as np
from scipy.spatial import cKDTree

# ---> THE FIX: Tell Blender where to look for config.py <---
if '/content' not in sys.path:
    sys.path.append('/content')
from config import CONFIG, GT_OVERRIDES

# --- THE FIX FOR COLAB/MATPLOTLIB ---
os.environ['MPLBACKEND'] = 'Agg'
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
# ------------------------------------

import bpy
import blendertoolbox as bt

# ==========================================
# 3. DERIVED PATHS
# ==========================================
DRIVE_SOURCE_DIR = os.path.join(CONFIG["DRIVE_BASE_PATH"], "PointCloud", "xyzFormat", CONFIG["PC_TYPE"])
DRIVE_OUTPUT_DIR = os.path.join(CONFIG["DRIVE_BASE_PATH"], "RenderImages", CONFIG["PC_TYPE"], f"{CONFIG['COLORMAP']}_colormap")

LOCAL_SOURCE_DIR = os.path.join(CONFIG["LOCAL_COLAB_BASE"], CONFIG["PC_TYPE"])
LOCAL_GROUND_TRUTH_PATH = os.path.join(LOCAL_SOURCE_DIR, CONFIG["GT_FILENAME"])


# ==========================================
# 4. PIPELINE FUNCTIONS
# ==========================================
def setup_colab_environment():
    print("--- Setting up Environment ---")
    os.makedirs(DRIVE_OUTPUT_DIR, exist_ok=True)

    if os.path.exists(LOCAL_SOURCE_DIR):
        shutil.rmtree(LOCAL_SOURCE_DIR)

    print(f"Copying point clouds from Drive to Local Colab Storage...")
    shutil.copytree(DRIVE_SOURCE_DIR, LOCAL_SOURCE_DIR)
    print("Copy complete!\n")


def render_point_clouds():
    print("--- Starting Render Process ---")

    ground_truth_points = np.loadtxt(LOCAL_GROUND_TRUTH_PATH)
    tree = cKDTree(ground_truth_points)

    for filename in os.listdir(LOCAL_SOURCE_DIR):
        if not filename.endswith(".xyz"):
            continue

        # 1. Determine if this specific file is the Ground Truth
        is_gt = (filename == CONFIG["GT_FILENAME"])

        # 2. Create the Active Config
        active_cfg = CONFIG.copy()
        if is_gt:
            active_cfg.update(GT_OVERRIDES)

        # 3. Output checking (UPDATED WITH FORCE_OVERWRITE FLAG)
        render_output = os.path.join(DRIVE_OUTPUT_DIR, f"{os.path.splitext(filename)[0]}.png")
        if os.path.exists(render_output) and not active_cfg["FORCE_OVERWRITE"]:
            print(f"Output already exists: {filename}. Skipping...")
            continue

        print(f"Processing: {filename} {'(GROUND TRUTH MODE)' if is_gt else ''}")

        # 4. Initialize Blender
        bt.blenderInit(
            active_cfg["IMG_RES_X"],
            active_cfg["IMG_RES_Y"],
            active_cfg["NUM_SAMPLES"],
            active_cfg["EXPOSURE"]
        )

        # 5. Load Points
        current_points = ground_truth_points if is_gt else np.loadtxt(os.path.join(LOCAL_SOURCE_DIR, filename))

        # 6. Apply Color Logic
        if is_gt:
            colormap = plt.get_cmap(active_cfg["COLORMAP"])
            min_color = colormap(0.0)[:3]
            colors = np.tile(min_color, (current_points.shape[0], 1))
        else:
            distances, _ = tree.query(current_points)
            max_distance = np.percentile(distances, 99)
            normalized_distances = np.clip(distances / max_distance, 0, 1)
            normalized_distances = np.log1p(normalized_distances) / np.log1p(1)
            colormap = plt.get_cmap(active_cfg["COLORMAP"])
            colors = colormap(normalized_distances)[:, :3]

        # 7. Setup Mesh and Materials
        mesh = bt.readNumpyPoints(
            current_points,
            active_cfg["OBJ_LOCATION"],
            active_cfg["OBJ_ROTATION"],
            active_cfg["OBJ_SCALE"]
        )
        mesh = bt.setPointColors(mesh, colors)

        ptColor = bt.colorObj(active_cfg["PT_COLOR"], 0.5, 1.0, 1.0, 0.0, 0.0)
        bt.setMat_pointCloudColored(mesh, ptColor, active_cfg["PT_SIZE"])

        # 8. Setup Environment
        cam = bt.setCamera(active_cfg["CAM_LOCATION"], active_cfg["LOOK_AT"], active_cfg["FOCAL_LENGTH"])
        sun = bt.setLight_sun(active_cfg["LIGHT_ANGLE"], active_cfg["LIGHT_STRENGTH"], active_cfg["SHADOW_SOFTNESS"])
        bt.setLight_ambient(color=active_cfg["AMBIENT_COLOR"])
        bt.shadowThreshold(alphaThreshold=active_cfg["SHADOW_THRESHOLD"], interpolationMode='CARDINAL')

        bpy.context.scene.use_nodes = True
        tree_nodes = bpy.context.scene.node_tree
        tree_nodes.nodes.clear()

        render_layers = tree_nodes.nodes.new('CompositorNodeRLayers')
        denoise_node = tree_nodes.nodes.new(type='CompositorNodeDenoise')
        composite = tree_nodes.nodes.new('CompositorNodeComposite')
        viewer = tree_nodes.nodes.new('CompositorNodeViewer')

        render_layers.location = (-300, 0)
        denoise_node.location = (0, 0)
        composite.location = (300, 0)
        viewer.location = (300, -200)

        tree_nodes.links.new(render_layers.outputs['Image'], denoise_node.inputs['Image'])
        tree_nodes.links.new(denoise_node.outputs['Image'], composite.inputs['Image'])
        tree_nodes.links.new(denoise_node.outputs['Image'], viewer.inputs['Image'])

        # 9. Save Colormap Gradient
        colormap_path = os.path.join(DRIVE_OUTPUT_DIR, f"{active_cfg['COLORMAP']}_colormap.png")
        if not os.path.exists(colormap_path):
            gradient = np.linspace(0, 1, 256).reshape(1, -1)
            gradient = np.vstack([gradient] * 50)
            plt.figure(figsize=(6, 1))
            plt.imshow(gradient, aspect="auto", cmap=active_cfg["COLORMAP"])
            plt.axis("off")
            plt.savefig(colormap_path, bbox_inches="tight", pad_inches=0, dpi=300)
            plt.close()
            print(f"Colormap saved at {colormap_path}")

        # 10. Save Blend File
        if active_cfg["SAVE_BLEND_FILE"]:
            blend_file_name = f"{os.path.splitext(filename)[0]}.blend"
            blend_file_path = os.path.join(DRIVE_OUTPUT_DIR, blend_file_name)
            bpy.ops.wm.save_mainfile(filepath=blend_file_path)
            print(f"Blend file saved at {blend_file_path}")

        # 11. Render
        bt.renderImage(render_output, cam)
        print(f"Render complete for {filename}\n")


if __name__ == "__main__":
    setup_colab_environment()
    render_point_clouds()
# Out:
# Overwriting render.py

# %%
#@title 2.3 Start Rendering Render

# !./blender-4.0.2-linux-x64/blender -b -P render.py
# Out:
# Blender 4.0.2 (hash 9be62e85b727 built 2023-12-05 08:48:50)
# --- Setting up Environment ---
# Copying point clouds from Drive to Local Colab Storage...
# Copy complete!
#
# --- Starting Render Process ---
# Processing: noisy_ellipsoid.xyz_gaussian_3.0_dmr.xyz
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7aa9a3cefe88>
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7aa9a3ceff98>
# Info: Saved "noisy_ellipsoid.xyz_gaussian_3.0_dmr.blend"
# Blend file saved at /content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/ellipsoid_3.0_PC/inferno_colormap/noisy_ellipsoid.xyz_gaussian_3.0_dmr.blend
# Fra:1 Mem:16.67M (Peak 16.67M) | Time:00:00.28 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | numpy point cloud object
# Fra:1 Mem:21.05M (Peak 21.05M) | Time:00:00.28 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:20.50M (Peak 21.05M) | Time:00:00.28 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:20.50M (Peak 21.05M) | Time:00:00.28 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:20.50M (Peak 41.07M) | Time:00:00.46 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:20.50M (Peak 41.07M) | Time:00:00.46 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:20.58M (Peak 41.07M) | Time:00:00.46 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:20.58M (Peak 41.07M) | Time:00:00.46 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:20.58M (Peak 41.07M) | Time:00:00.46 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:20.58M (Peak 41.07M) | Time:00:00.46 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:20.58M (Peak 41.07M) | Time:00:00.46 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:20.58M (Peak 41.07M) | Time:00:00.46 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:20.59M (Peak 41.07M) | Time:00:00.46 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:20.59M (Peak 41.07M) | Time:00:00.46 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:20.59M (Peak 41.07M) | Time:00:00.46 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:20.59M (Peak 41.07M) | Time:00:00.46 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:20.59M (Peak 41.07M) | Time:00:00.46 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:21.68M (Peak 41.07M) | Time:00:00.46 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:21.68M (Peak 41.07M) | Time:00:00.47 | Mem:1.10M, Peak:1.10M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building BVH
# Fra:1 Mem:21.68M (Peak 41.07M) | Time:00:00.47 | Mem:1.10M, Peak:1.10M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building OptiX acceleration structure
# Fra:1 Mem:21.68M (Peak 41.07M) | Time:00:00.47 | Mem:1.10M, Peak:1.10M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building BVH
# Fra:1 Mem:21.68M (Peak 41.07M) | Time:00:00.47 | Mem:1.10M, Peak:1.10M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building OptiX acceleration structure
# Fra:1 Mem:21.68M (Peak 41.07M) | Time:00:00.47 | Mem:2.77M, Peak:10.55M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:21.68M (Peak 41.07M) | Time:00:00.47 | Mem:2.77M, Peak:10.55M | Scene, ViewLayer | Updating Scene BVH | Building OptiX acceleration structure
# Fra:1 Mem:21.68M (Peak 41.07M) | Time:00:00.47 | Mem:2.78M, Peak:10.55M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:21.68M (Peak 41.07M) | Time:00:00.47 | Mem:2.78M, Peak:10.55M | Scene, ViewLayer | Updating Mesh | Copying Point clouds to device
# Fra:1 Mem:23.05M (Peak 41.07M) | Time:00:00.47 | Mem:4.14M, Peak:10.55M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:23.05M (Peak 41.07M) | Time:00:00.47 | Mem:4.14M, Peak:10.55M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:23.05M (Peak 41.07M) | Time:00:00.48 | Mem:4.14M, Peak:10.55M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:23.05M (Peak 41.07M) | Time:00:00.48 | Mem:4.14M, Peak:10.55M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:23.05M (Peak 41.07M) | Time:00:00.48 | Mem:4.14M, Peak:10.55M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:23.05M (Peak 41.07M) | Time:00:00.48 | Mem:4.23M, Peak:10.55M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:23.05M (Peak 41.07M) | Time:00:00.48 | Mem:4.23M, Peak:10.55M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:1 Mem:23.05M (Peak 41.07M) | Time:00:00.48 | Mem:4.23M, Peak:10.55M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:23.05M (Peak 41.07M) | Time:00:00.48 | Mem:4.23M, Peak:10.55M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:24.05M (Peak 41.07M) | Time:00:00.48 | Mem:5.23M, Peak:10.55M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:24.05M (Peak 41.07M) | Time:00:00.48 | Mem:5.14M, Peak:10.55M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:24.05M (Peak 41.07M) | Time:00:00.48 | Mem:5.23M, Peak:10.55M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:24.05M (Peak 41.07M) | Time:00:00.48 | Mem:5.23M, Peak:10.55M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:28.06M (Peak 41.07M) | Time:00:00.49 | Mem:333.23M, Peak:333.23M | Scene, ViewLayer | Sample 0/100
# Fra:1 Mem:62.39M (Peak 62.39M) | Time:00:00.51 | Remaining:00:02.38 | Mem:367.56M, Peak:367.56M | Scene, ViewLayer | Sample 1/100
# Fra:1 Mem:62.40M (Peak 62.40M) | Time:00:01.66 | Remaining:00:00.29 | Mem:367.58M, Peak:367.58M | Scene, ViewLayer | Sample 80/100
# Fra:1 Mem:62.40M (Peak 62.40M) | Time:00:01.75 | Remaining:00:00.05 | Mem:367.58M, Peak:367.58M | Scene, ViewLayer | Sample 96/100
# Fra:1 Mem:77.66M (Peak 108.18M) | Time:00:01.84 | Mem:367.58M, Peak:367.58M | Scene, ViewLayer | Sample 100/100
# Fra:1 Mem:77.66M (Peak 108.18M) | Time:00:01.84 | Mem:367.58M, Peak:367.58M | Scene, ViewLayer | Finished
# Fra:1 Mem:31.38M (Peak 108.18M) | Time:00:01.95 | Compositing
# Fra:1 Mem:31.38M (Peak 108.18M) | Time:00:01.95 | Compositing | Determining resolution
# Fra:1 Mem:31.38M (Peak 108.18M) | Time:00:01.95 | Compositing | Initializing execution
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.93 | Compositing | Tile 1-16
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.93 | Compositing | Tile 2-16
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.93 | Compositing | Tile 4-16
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.93 | Compositing | Tile 3-16
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.93 | Compositing | Tile 5-16
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.93 | Compositing | Tile 6-16
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.94 | Compositing | Tile 7-16
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.94 | Compositing | Tile 8-16
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.94 | Compositing | Tile 9-16
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.94 | Compositing | Tile 10-16
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.94 | Compositing | Tile 11-16
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.94 | Compositing | Tile 12-16
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.94 | Compositing | Tile 13-16
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.94 | Compositing | Tile 14-16
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.94 | Compositing | Tile 15-16
# Fra:1 Mem:172.60M (Peak 172.60M) | Time:00:16.95 | Compositing | Tile 16-16
# Fra:1 Mem:172.53M (Peak 172.60M) | Time:00:16.95 | Compositing | De-initializing execution
# Saved: '/content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/ellipsoid_3.0_PC/inferno_colormap/noisy_ellipsoid.xyz_gaussian_3.0_dmr.png'
# Time: 00:17.32 (Saving: 00:00.36)
#
# Render complete for noisy_ellipsoid.xyz_gaussian_3.0_dmr.xyz
#
# Processing: denoised_noisy_ellipsoid.xyz_gaussian_3.0_ours.xyz
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7aa9a3cefe88>
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7aa9a3ceff98>
# Colormap saved at /content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/ellipsoid_3.0_PC/inferno_colormap/inferno_colormap.png
# Info: Saved "denoised_noisy_ellipsoid.xyz_gaussian_3.0_ours.blend"
# Blend file saved at /content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/ellipsoid_3.0_PC/inferno_colormap/denoised_noisy_ellipsoid.xyz_gaussian_3.0_ours.blend
# Fra:1 Mem:15.99M (Peak 15.99M) | Time:00:00.24 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | numpy point cloud object
# Fra:1 Mem:19.71M (Peak 19.71M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:19.20M (Peak 19.71M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:19.20M (Peak 19.71M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:19.20M (Peak 39.77M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:19.20M (Peak 39.77M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:19.29M (Peak 39.77M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:19.29M (Peak 39.77M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:19.29M (Peak 39.77M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:19.29M (Peak 39.77M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:19.29M (Peak 39.77M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:19.29M (Peak 39.77M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:19.29M (Peak 39.77M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:19.29M (Peak 39.77M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:19.29M (Peak 39.77M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:19.29M (Peak 39.77M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:19.29M (Peak 39.77M) | Time:00:00.33 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:20.22M (Peak 39.77M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:20.21M (Peak 39.77M) | Time:00:00.34 | Mem:0.94M, Peak:0.94M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building BVH
# Fra:1 Mem:20.21M (Peak 39.77M) | Time:00:00.34 | Mem:0.94M, Peak:0.94M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building OptiX acceleration structure
# Fra:1 Mem:20.21M (Peak 39.77M) | Time:00:00.34 | Mem:0.94M, Peak:0.94M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building BVH
# Fra:1 Mem:20.21M (Peak 39.77M) | Time:00:00.34 | Mem:0.94M, Peak:0.94M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building OptiX acceleration structure
# Fra:1 Mem:20.21M (Peak 39.77M) | Time:00:00.34 | Mem:2.36M, Peak:8.95M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:20.21M (Peak 39.77M) | Time:00:00.34 | Mem:2.36M, Peak:8.95M | Scene, ViewLayer | Updating Scene BVH | Building OptiX acceleration structure
# Fra:1 Mem:20.21M (Peak 39.77M) | Time:00:00.34 | Mem:2.37M, Peak:8.95M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:20.21M (Peak 39.77M) | Time:00:00.34 | Mem:2.37M, Peak:8.95M | Scene, ViewLayer | Updating Mesh | Copying Point clouds to device
# Fra:1 Mem:21.38M (Peak 39.77M) | Time:00:00.34 | Mem:3.53M, Peak:8.95M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:21.38M (Peak 39.77M) | Time:00:00.34 | Mem:3
| Scene, ViewLayer | Finished
# Fra:1 Mem:30.12M (Peak 104.84M) | Time:00:01.91 | Compositing
# Fra:1 Mem:30.12M (Peak 104.84M) | Time:00:01.91 | Compositing | Determining resolution
# Fra:1 Mem:30.12M (Peak 104.84M) | Time:00:01.91 | Compositing | Initializing execution
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.13 | Compositing | Tile 1-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.13 | Compositing | Tile 2-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.14 | Compositing | Tile 3-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.14 | Compositing | Tile 4-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.14 | Compositing | Tile 5-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.14 | Compositing | Tile 6-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.15 | Compositing | Tile 7-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.15 | Compositing | Tile 8-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.15 | Compositing | Tile 9-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.16 | Compositing | Tile 10-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.16 | Compositing | Tile 11-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.16 | Compositing | Tile 12-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.16 | Compositing | Tile 13-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.17 | Compositing | Tile 14-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.17 | Compositing | Tile 15-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:15.17 | Compositing | Tile 16-16
# Fra:1 Mem:171.27M (Peak 171.33M) | Time:00:15.17 | Compositing | De-initializing execution
# Saved: '/content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/ellipsoid_3.0_PC/inferno_colormap/noisy_ellipsoid.xyz_gaussian_3.0_score.png'
# Time: 00:15.59 (Saving: 00:00.40)
#
# Render complete for noisy_ellipsoid.xyz_gaussian_3.0_score.xyz
#
# Processing: ellipsoid.xyz (GROUND TRUTH MODE)
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7aa9a3cefe88>
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7aa9a3ceff98>
# Info: Saved "ellipsoid.blend"
# Blend file saved at /content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/ellipsoid_3.0_PC/inferno_colormap/ellipsoid.blend
# Fra:1 Mem:15.32M (Peak 15.32M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | numpy point cloud object
# Fra:1 Mem:18.37M (Peak 18.37M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:17.91M (Peak 18.37M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:17.91M (Peak 18.37M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:17.91M (Peak 38.48M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:17.91M (Peak 38.48M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.43 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.44 | Mem:0.77M, Peak:0.77M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building BVH
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.44 | Mem:0.77M, Peak:0.77M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building OptiX acceleration structure
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.44 | Mem:0.77M, Peak:0.77M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building BVH
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.44 | Mem:0.77M, Peak:0.77M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building OptiX acceleration structure
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.44 | Mem:1.92M, Peak:7.36M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.44 | Mem:1.92M, Peak:7.36M | Scene, ViewLayer | Updating Scene BVH | Building OptiX acceleration structure
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.44 | Mem:1.92M, Peak:7.36M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.44 | Mem:1.92M, Peak:7.36M | Scene, ViewLayer | Updating Mesh | Copying Point clouds to device
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.44 | Mem:2.87M, Peak:7.36M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.44 | Mem:2.87M, Peak:7.36M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.44 | Mem:2.87M, Peak:7.36M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.44 | Mem:2.87M, Peak:7.36M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.44 | Mem:2.87M, Peak:7.36M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.44 | Mem:2.95M, Peak:7.36M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.44 | Mem:2.95M, Peak:7.36M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.44 | Mem:2.95M, Peak:7.36M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.44 | Mem:2.95M, Peak:7.36M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:20.71M (Peak 38.48M) | Time:00:00.44 | Mem:3.95M, Peak:7.36M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:20.72M (Peak 38.48M) | Time:00:00.45 | Mem:3.87M, Peak:7.36M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:20.72M (Peak 38.48M) | Time:00:00.45 | Mem:3.96M, Peak:7.36M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:20.72M (Peak 38.48M) | Time:00:00.45 | Mem:3.96M, Peak:7.36M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:24.72M (Peak 38.48M) | Time:00:00.45 | Mem:331.96M, Peak:331.96M | Scene, ViewLayer | Sample 0/100
# Fra:1 Mem:59.05M (Peak 59.05M) | Time:00:00.47 | Remaining:00:01.87 | Mem:366.29M, Peak:366.29M | Scene, ViewLayer | Sample 1/100
# Fra:1 Mem:59.06M (Peak 59.06M) | Time:00:01.38 | Remaining:00:00.23 | Mem:366.30M, Peak:366.30M | Scene, ViewLayer | Sample 80/100
# Fra:1 Mem:59.06M (Peak 59.06M) | Time:00:01.39 | Remaining:00:00.03 | Mem:366.30M, Peak:366.30M | Scene, ViewLayer | Sample 96/100
# Fra:1 Mem:74.32M (Peak 104.84M) | Time:00:01.47 | Mem:366.30M, Peak:366.30M | Scene, ViewLayer | Sample 100/100
# Fra:1 Mem:74.32M (Peak 104.84M) | Time:00:01.47 | Mem:366.30M, Peak:366.30M | Scene, ViewLayer | Finished
# Fra:1 Mem:30.12M (Peak 104.84M) | Time:00:01.59 | Compositing
# Fra:1 Mem:30.12M (Peak 104.84M) | Time:00:01.59 | Compositing | Determining resolution
# Fra:1 Mem:30.12M (Peak 104.84M) | Time:00:01.59 | Compositing | Initializing execution
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.66 | Compositing | Tile 1-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.67 | Compositing | Tile 2-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.67 | Compositing | Tile 3-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.67 | Compositing | Tile 4-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.68 | Compositing | Tile 5-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.68 | Compositing | Tile 6-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.68 | Compositing | Tile 7-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.68 | Compositing | Tile 8-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.69 | Compositing | Tile 9-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.69 | Compositing | Tile 10-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.69 | Compositing | Tile 11-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.69 | Compositing | Tile 12-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.70 | Compositing | Tile 13-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.70 | Compositing | Tile 14-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.70 | Compositing | Tile 15-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:13.71 | Compositing | Tile 16-16
# Fra:1 Mem:171.27M (Peak 171.33M) | Time:00:13.71 | Compositing | De-initializing execution
# Saved: '/content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/ellipsoid_3.0_PC/inferno_colormap/ellipsoid.png'
# Time: 00:14.15 (Saving: 00:00.43)
#
# Render complete for ellipsoid.xyz
#
# Processing: noisy_ellipsoid_gaussian_3.0_wloped.xyz
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7aa9a3cefe88>
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7aa9a3ceff98>
# Info: Saved "noisy_ellipsoid_gaussian_3.0_wloped.blend"
# Blend file saved at /content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/ellipsoid_3.0_PC/inferno_colormap/noisy_ellipsoid_gaussian_3.0_wloped.blend
# Fra:1 Mem:14.48M (Peak 14.48M) | Time:00:00.31 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | numpy point cloud object
# Fra:1 Mem:16.71M (Peak 16.71M) | Time:00:00.31 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# ...
# Saved: '/content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/ellipsoid_3.0_PC/inferno_colormap/delnoise_240.05_noisy_ellipsoid.xyz_gaussian_3.0.png'
# Time: 00:16.72 (Saving: 00:00.37)
#
# Render complete for delnoise_240.05_noisy_ellipsoid.xyz_gaussian_3.0.xyz
#
# Processing: noisy_ellipsoid.xyz_gaussian_3.0.xyz
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7aa9a3cefe88>
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7aa9a3ceff98>
# Info: Saved "noisy_ellipsoid.xyz_gaussian_3.0.blend"
# Blend file saved at /content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/ellipsoid_3.0_PC/inferno_colormap/noisy_ellipsoid.xyz_gaussian_3.0.blend
# Fra:1 Mem:15.32M (Peak 15.32M) | Time:00:00.24 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | numpy point cloud object
# Fra:1 Mem:18.37M (Peak 18.37M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:17.91M (Peak 18.37M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:17.91M (Peak 18.37M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:17.91M (Peak 38.48M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:17.91M (Peak 38.48M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:17.99M (Peak 38.48M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.34 | Mem:0.77M, Peak:0.77M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building BVH
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.34 | Mem:0.77M, Peak:0.77M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building OptiX acceleration structure
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.34 | Mem:0.77M, Peak:0.77M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building BVH
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.34 | Mem:0.77M, Peak:0.77M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building OptiX acceleration structure
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.34 | Mem:1.98M, Peak:7.36M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.34 | Mem:1.98M, Peak:7.36M | Scene, ViewLayer | Updating Scene BVH | Building OptiX acceleration structure
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.34 | Mem:1.98M, Peak:7.36M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:18.76M (Peak 38.48M) | Time:00:00.34 | Mem:1.98M, Peak:7.36M | Scene, ViewLayer | Updating Mesh | Copying Point clouds to device
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.34 | Mem:2.94M, Peak:7.36M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.34 | Mem:2.94M, Peak:7.36M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.34 | Mem:2.94M, Peak:7.36M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.34 | Mem:2.94M, Peak:7.36M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.34 | Mem:2.94M, Peak:7.36M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.34 | Mem:3.02M, Peak:7.36M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.34 | Mem:3.02M, Peak:7.36M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.34 | Mem:3.02M, Peak:7.36M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:19.71M (Peak 38.48M) | Time:00:00.34 | Mem:3.02M, Peak:7.36M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:20.71M (Peak 38.48M) | Time:00:00.34 | Mem:4.02M, Peak:7.36M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:20.72M (Peak 38.48M) | Time:00:00.35 | Mem:3.94M, Peak:7.36M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:20.72M (Peak 38.48M) | Time:00:00.35 | Mem:4.02M, Peak:7.36M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:20.72M (Peak 38.48M) | Time:00:00.35 | Mem:4.02M, Peak:7.36M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:24.72M (Peak 38.48M) | Time:00:00.35 | Mem:332.02M, Peak:332.02M | Scene, ViewLayer | Sample 0/100
# Fra:1 Mem:59.05M (Peak 59.05M) | Time:00:00.38 | Remaining:00:02.63 | Mem:366.36M, Peak:366.36M | Scene, ViewLayer | Sample 1/100
# Fra:1 Mem:59.06M (Peak 59.06M) | Time:00:01.64 | Remaining:00:00.32 | Mem:366.37M, Peak:366.37M | Scene, ViewLayer | Sample 80/100
# Fra:1 Mem:59.06M (Peak 59.06M) | Time:00:01.81 | Remaining:00:00.06 | Mem:366.37M, Peak:366.37M | Scene, ViewLayer | Sample 96/100
# Fra:1 Mem:74.32M (Peak 104.84M) | Time:00:01.92 | Mem:366.37M, Peak:366.37M | Scene, ViewLayer | Sample 100/100
# Fra:1 Mem:74.32M (Peak 104.84M) | Time:00:01.92 | Mem:366.37M, Peak:366.37M | Scene, ViewLayer | Finished
# Fra:1 Mem:30.12M (Peak 104.84M) | Time:00:02.02 | Compositing
# Fra:1 Mem:30.12M (Peak 104.84M) | Time:00:02.02 | Compositing | Determining resolution
# Fra:1 Mem:30.12M (Peak 104.84M) | Time:00:02.02 | Compositing | Initializing execution
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.91 | Compositing | Tile 1-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.91 | Compositing | Tile 2-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.92 | Compositing | Tile 3-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.92 | Compositing | Tile 4-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.92 | Compositing | Tile 5-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.92 | Compositing | Tile 6-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.93 | Compositing | Tile 7-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.93 | Compositing | Tile 8-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.93 | Compositing | Tile 9-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.93 | Compositing | Tile 10-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.93 | Compositing | Tile 11-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.94 | Compositing | Tile 12-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.94 | Compositing | Tile 13-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.94 | Compositing | Tile 14-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.94 | Compositing | Tile 15-16
# Fra:1 Mem:171.33M (Peak 171.33M) | Time:00:16.94 | Compositing | Tile 16-16
# Fra:1 Mem:171.27M (Peak 171.33M) | Time:00:16.94 | Compositing | De-initializing execution
# Saved: '/content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/ellipsoid_3.0_PC/inferno_colormap/noisy_ellipsoid.xyz_gaussian_3.0.png'
# Time: 00:17.30 (Saving: 00:00.34)
#
# Render complete for noisy_ellipsoid.xyz_gaussian_3.0.xyz
#
# Processing: AD_noisy_ellipsoid_gaussian_3.0.xyz
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7aa9a3cefe88>
# using device:  <bpy_struct, CyclesDeviceSettings("Tesla T4") at 0x7aa9a3ceff98>
# Info: Saved "AD_noisy_ellipsoid_gaussian_3.0.blend"
# Blend file saved at /content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/ellipsoid_3.0_PC/inferno_colormap/AD_noisy_ellipsoid_gaussian_3.0.blend
# Fra:1 Mem:16.74M (Peak 16.74M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Synchronizing object | numpy point cloud object
# Fra:1 Mem:21.20M (Peak 21.20M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Initializing
# Fra:1 Mem:20.65M (Peak 21.20M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Waiting for render to start
# Fra:1 Mem:20.65M (Peak 21.20M) | Time:00:00.25 | Mem:0.00M, Peak:0.00M | Scene, ViewLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:20.65M (Peak 41.22M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Scene
# Fra:1 Mem:20.65M (Peak 41.22M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Shaders
# Fra:1 Mem:20.73M (Peak 41.22M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Procedurals
# Fra:1 Mem:20.73M (Peak 41.22M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Background
# Fra:1 Mem:20.73M (Peak 41.22M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Camera
# Fra:1 Mem:20.73M (Peak 41.22M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes Flags
# Fra:1 Mem:20.73M (Peak 41.22M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects
# Fra:1 Mem:20.73M (Peak 41.22M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:20.73M (Peak 41.22M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:20.73M (Peak 41.22M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems
# Fra:1 Mem:20.73M (Peak 41.22M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:20.73M (Peak 41.22M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Meshes
# Fra:1 Mem:20.73M (Peak 41.22M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:21.85M (Peak 41.22M) | Time:00:00.34 | Mem:0.01M, Peak:0.01M | Scene, ViewLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:21.85M (Peak 41.22M) | Time:00:00.34 | Mem:1.12M, Peak:1.12M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building BVH
# Fra:1 Mem:21.85M (Peak 41.22M) | Time:00:00.34 | Mem:1.12M, Peak:1.12M | Scene, ViewLayer | Updating Geometry BVH numpy point cloud 1/2 | Building OptiX acceleration structure
# Fra:1 Mem:21.85M (Peak 41.22M) | Time:00:00.34 | Mem:1.12M, Peak:1.12M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building BVH
# Fra:1 Mem:21.85M (Peak 41.22M) | Time:00:00.34 | Mem:1.12M, Peak:1.12M | Scene, ViewLayer | Updating Geometry BVH PointCloud 2/2 | Building OptiX acceleration structure
# Fra:1 Mem:21.85M (Peak 41.22M) | Time:00:00.34 | Mem:2.44M, Peak:10.73M | Scene, ViewLayer | Updating Scene BVH | Building
# Fra:1 Mem:21.85M (Peak 41.22M) | Time:00:00.34 | Mem:2.44M, Peak:10.73M | Scene, ViewLayer | Updating Scene BVH | Building OptiX acceleration structure
# Fra:1 Mem:21.85M (Peak 41.22M) | Time:00:00.34 | Mem:2.45M, Peak:10.73M | Scene, ViewLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:21.85M (Peak 41.22M) | Time:00:00.34 | Mem:2.45M, Peak:10.73M | Scene, ViewLayer | Updating Mesh | Copying Point clouds to device
# Fra:1 Mem:23.24M (Peak 41.22M) | Time:00:00.35 | Mem:3.84M, Peak:10.73M | Scene, ViewLayer | Updating Objects Flags
# Fra:1 Mem:23.24M (Peak 41.22M) | Time:00:00.35 | Mem:3.84M, Peak:10.73M | Scene, ViewLayer | Updating Primitive Offsets
# Fra:1 Mem:23.24M (Peak 41.22M) | Time:00:00.35 | Mem:3.84M, Peak:10.73M | Scene, ViewLayer | Updating Images
# Fra:1 Mem:23.24M (Peak 41.22M) | Time:00:00.35 | Mem:3.84M, Peak:10.73M | Scene, ViewLayer | Updating Camera Volume
# Fra:1 Mem:23.24M (Peak 41.22M) | Time:00:00.35 | Mem:3.84M, Peak:10.73M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:23.24M (Peak 41.22M) | Time:00:00.35 | Mem:3.92M, Peak:10.73M | Scene, ViewLayer | Updating Lights
# Fra:1 Mem:23.24M (Peak 41.22M) | Time:00:00.35 | Mem:3.92M, Peak:10.73M | Scene, ViewLayer | Updating Lights | Computing distribution
# Fra:1 Mem:23.24M (Peak 41.22M) | Time:00:00.35 | Mem:3.92M, Peak:10.73M | Scene, ViewLayer | Updating Lights | Computing tree
# Fra:1 Mem:23.24M (Peak 41.22M) | Time:00:00.35 | Mem:3.92M, Peak:10.73M | Scene, ViewLayer | Updating Integrator
# Fra:1 Mem:24.24M (Peak 41.22M) | Time:00:00.35 | Mem:4.92M, Peak:10.73M | Scene, ViewLayer | Updating Film
# Fra:1 Mem:24.24M (Peak 41.22M) | Time:00:00.35 | Mem:4.84M, Peak:10.73M | Scene, ViewLayer | Updating Lookup Tables
# Fra:1 Mem:24.24M (Peak 41.22M) | Time:00:00.35 | Mem:4.92M, Peak:10.73M | Scene, ViewLayer | Updating Baking
# Fra:1 Mem:24.24M (Peak 41.22M) | Time:00:00.35 | Mem:4.92M, Peak:10.73M | Scene, ViewLayer | Updating Device | Writing constant memory
# Fra:1 Mem:28.24M (Peak 41.22M) | Time:00:00.35 | Mem:332.92M, Peak:332.92M | Scene, ViewLayer | Sample 0/100
# Fra:1 Mem:62.58M (Peak 62.58M) | Time:00:00.37 | Remaining:00:02.11 | Mem:367.26M, Peak:367.26M | Scene, ViewLayer | Sample 1/100
# Fra:1 Mem:62.59M (Peak 62.59M) | Time:00:01.11 | Remaining:00:00.18 | Mem:367.27M, Peak:367.27M | Scene, ViewLayer | Sample 80/100
# Fra:1 Mem:62.59M (Peak 62.59M) | Time:00:01.17 | Remaining:00:00.03 | Mem:367.27M, Peak:367.27M | Scene, ViewLayer | Sample 96/100
# Fra:1 Mem:77.85M (Peak 108.37M) | Time:00:01.24 | Mem:367.27M, Peak:367.27M | Scene, ViewLayer | Sample 100/100
# Fra:1 Mem:77.85M (Peak 108.37M) | Time:00:01.24 | Mem:367.27M, Peak:367.27M | Scene, ViewLayer | Finished
# Fra:1 Mem:31.46M (Peak 108.37M) | Time:00:01.35 | Compositing
# Fra:1 Mem:31.46M (Peak 108.37M) | Time:00:01.35 | Compositing | Determining resolution
# Fra:1 Mem:31.46M (Peak 108.37M) | Time:00:01.35 | Compositing | Initializing execution
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.63 | Compositing | Tile 2-16
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.63 | Compositing | Tile 1-16
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.63 | Compositing | Tile 3-16
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.63 | Compositing | Tile 4-16
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.64 | Compositing | Tile 5-16
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.64 | Compositing | Tile 6-16
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.64 | Compositing | Tile 7-16
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.64 | Compositing | Tile 8-16
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.64 | Compositing | Tile 9-16
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.64 | Compositing | Tile 10-16
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.64 | Compositing | Tile 11-16
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.64 | Compositing | Tile 12-16
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.65 | Compositing | Tile 13-16
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.65 | Compositing | Tile 14-16
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.65 | Compositing | Tile 15-16
# Fra:1 Mem:172.67M (Peak 172.67M) | Time:00:16.65 | Compositing | Tile 16-16
# Fra:1 Mem:172.61M (Peak 172.67M) | Time:00:16.65 | Compositing | De-initializing execution
# Saved: '/content/drive/MyDrive/PyBlender_Render_Farm/RenderImages/ellipsoid_3.0_PC/inferno_colormap/AD_noisy_ellipsoid_gaussian_3.0.png'
# Time: 00:16.90 (Saving: 00:00.24)
#
# Render complete for AD_noisy_ellipsoid_gaussian_3.0.xyz
#
#
# Blender quit

# %%
#@title Extra: 3D PointCloud Visualizer
import numpy as np
import plotly.graph_objs as go

# 1. PATH TO YOUR POINT CLOUD
# Point this to any .xyz file you want to inspect (either on Drive or Local Colab storage)
PC_PATH = "/content/local_data/ccylinder_scaled_PC_new/AD_ccylinder_gaussian_3.5.xyz"

def view_point_cloud(filepath, max_points=100000):
    print(f"Loading {filepath}...")
    try:
        points = np.loadtxt(filepath)
    except Exception as e:
        print(f"Error loading file: {e}")
        return

    # 2. OPTIMIZATION
    # Browsers will crash if you try to render millions of points in Plotly.
    # If the point cloud is huge, we randomly sample it down to keep it interactive.
    if len(points) > max_points:
        print(f"Subsampling from {len(points)} to {max_points} points for smooth viewing...")
        indices = np.random.choice(len(points), max_points, replace=False)
        points = points[indices]

    x, y, z = points[:, 0], points[:, 1], points[:, 2]

    # Calculate center bounding box for reference
    center_x = (np.max(x) + np.min(x)) / 2
    center_y = (np.max(y) + np.min(y)) / 2
    center_z = (np.max(z) + np.min(z)) / 2
    print(f"\n--- Point Cloud Stats ---")
    print(f"X range: {np.min(x):.2f} to {np.max(x):.2f} (Center: {center_x:.2f})")
    print(f"Y range: {np.min(y):.2f} to {np.max(y):.2f} (Center: {center_y:.2f})")
    print(f"Z range: {np.min(z):.2f} to {np.max(z):.2f} (Center: {center_z:.2f})")

    # 3. BUILD THE INTERACTIVE PLOT
    print("\nGenerating interactive 3D viewer...")
    fig = go.Figure(data=[go.Scatter3d(
        x=x, y=y, z=z,
        mode='markers',
        marker=dict(
            size=1.5,
            color=z,                 # Color points by height to give depth
            colorscale='Viridis',
            opacity=0.8
        )
    )])

    # Lock the aspect ratio so the object doesn't stretch weirdly
    fig.update_layout(
        scene=dict(
            aspectmode='data',
            xaxis_title='X Axis',
            yaxis_title='Y Axis',
            zaxis_title='Z Axis'
        ),
        margin=dict(l=0, r=0, b=0, t=0),
        height=700
    )

    fig.show()

# Run the viewer
view_point_cloud(PC_PATH)
# Out:
# Loading /content/local_data/ccylinder_scaled_PC_new/AD_ccylinder_gaussian_3.5.xyz...
# Error loading file: /content/local_data/ccylinder_scaled_PC_new/AD_ccylinder_gaussian_3.5.xyz not found.
