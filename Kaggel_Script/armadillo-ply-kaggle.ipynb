# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahendra2409/PyBlender/blob/main/Kaggel_Script/armadillo-ply-kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# <a href="https://kaggle.com/kernels/welcome?src=https://github.com/Mahendra2409/PyBlender/blob/main/Kaggel_Script/armadillo-ply-kaggle.ipynb" target="_parent"><img src="https://img.shields.io/badge/Open_in-Kaggle-20BEFF?logo=kaggle&logoColor=white" alt="Open In Kaggle"/></a>
# <a href="https://drive.google.com/drive/folders/1sj-RqD5HRypGx-ZLqXpvyzY1CN84qJu-?usp=drive_link" target="_parent"><img src="https://img.shields.io/badge/PyBlender_Render_Farm-blue?logo=googledrive&logoColor=white" alt="PyBlender_Render_Farm"/></a>

# %% [markdown]
# # 🦔 Armadillo PLY Renderer (Kaggle)
#
# Renders `.ply` format armadillo models with **ceramic material** using Blender Cycles on Kaggle's dual T4 GPUs.
#
# | Aspect | Value |
# |---|---|
# | Format | `.ply` mesh |
# | Material | Ceramic (derekBlue) |
# | Loader | `bt.readMesh()` |
# | GPU | Dual T4 + OptiX denoiser |
# | Output | GCS `gs://pyblender-render-farm/RenderImages/plyFormat/armadillo_PLY/` |

# %%
# @title 0. WandB Authentication
# !pip install wandb -q
import wandb
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
wandb_api = user_secrets.get_secret("WANDB_API_KEY")
wandb.login(key=wandb_api)

# %%
# @title 1. Install Dependencies & Toolbox
# !wget -nc -q https://download.blender.org/release/Blender4.0/blender-4.0.2-linux-x64.tar.xz
# !tar -xf blender-4.0.2-linux-x64.tar.xz

# !./blender-4.0.2-linux-x64/4.0/python/bin/python3.10 -m ensurepip --upgrade > /dev/null 2>&1
# !./blender-4.0.2-linux-x64/4.0/python/bin/python3.10 -m pip install \
    scipy matplotlib numpy wandb blendertoolbox plotly google-cloud-storage \
    -q --no-input --disable-pip-version-check

# !git clone https://github.com/HTDerekLiu/BlenderToolbox.git
# !mv BlenderToolbox/blendertoolbox /kaggle/working/

# %%
#@title 2. Authenticate Google Cloud Storage
import os, json
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
gcs_key_json = user_secrets.get_secret("GCS_SERVICE_ACCOUNT_KEY")

GCS_KEY_PATH = "/tmp/gcs_service_account.json"
with open(GCS_KEY_PATH, "w") as f:
    f.write(gcs_key_json)

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = GCS_KEY_PATH
print(f"GCS credentials saved to {GCS_KEY_PATH}")

from google.cloud import storage
client = storage.Client()
bucket = client.bucket("pyblender-render-farm")
try:
    next(bucket.list_blobs(max_results=1), None)
    print("SUCCESS: Connected to gs://pyblender-render-farm")
except Exception as e:
    print(f"WARNING: Could not verify bucket: {e}")

# %%
#@title 3. Download PLY data from GCS to local
import os
from google.cloud import storage

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/tmp/gcs_service_account.json"
client = storage.Client()
bucket = client.bucket("pyblender-render-farm")

GCS_PLY_PREFIX = "PointCloud/plyFormat/armadillo_PLY/"
LOCAL_PLY_DIR = "/kaggle/working/local_data/armadillo_PLY"
os.makedirs(LOCAL_PLY_DIR, exist_ok=True)

blobs = list(bucket.list_blobs(prefix=GCS_PLY_PREFIX))
print(f"Found {len(blobs)} files in gs://pyblender-render-farm/{GCS_PLY_PREFIX}")

for blob in blobs:
    fname = os.path.basename(blob.name)
    if not fname:
        continue
    dest = os.path.join(LOCAL_PLY_DIR, fname)
    if not os.path.exists(dest):
        blob.download_to_filename(dest)
        print(f"  Downloaded: {fname}")
    else:
        print(f"  Exists: {fname}")

print(f"\nAll files ready at {LOCAL_PLY_DIR}")
# !ls -la {LOCAL_PLY_DIR}

# %%
# %%writefile config.py

CONFIG = {
    # --- Output Controls ---
    "SAVE_BLEND_FILE": False,
    "FORCE_OVERWRITE": False,

    # --- Kaggle Paths ---
    "LOCAL_INPUT_DIR": "/kaggle/working/local_data/armadillo_PLY",
    "KAGGLE_OUTPUT_DIR": "/kaggle/working/RenderImages",
    "PC_TYPE": "armadillo_PLY",

    # --- Google Cloud Storage ---
    "GCS_BUCKET_NAME": "pyblender-render-farm",
    "GCS_BASE_PATH": "RenderImages/plyFormat",
    "GCS_KEY_PATH": "/tmp/gcs_service_account.json",

    # --- Object Transforms ---
    "OBJ_LOCATION": (0.616392, -0.390241, -0.591646),
    "OBJ_ROTATION": (466.067, -2.68728, -306.609),
    "OBJ_SCALE": (0.006976, 0.006976, 0.006976),

    # --- Blender Render Settings ---
    "IMG_RES_X": 2000,
    "IMG_RES_Y": 2000,
    "NUM_SAMPLES": 100,
    "EXPOSURE": 1.5,

    # --- Subdivision ---
    "SUBDIVISION_LEVEL": 2,

    # --- Camera ---
    "CAM_LOCATION": (-1.9494, 1.5553, 0.71451),
    "LOOK_AT": (0, 0, 0),
    "FOCAL_LENGTH": 45,

    # --- Lighting ---
    "LIGHT_ANGLE": (-17.5966, -47, -384),
    "LIGHT_STRENGTH": 2,
    "SHADOW_SOFTNESS": 0.3,
    "AMBIENT_COLOR": (0.1, 0.1, 0.1, 1),
    "SHADOW_THRESHOLD": 0.05,
}

# %%
# %%writefile render_ply.py

import os, sys, time, threading, queue

if '/kaggle/working' not in sys.path:
    sys.path.append('/kaggle/working')
from config import CONFIG

import bpy
import blendertoolbox as bt
import wandb


# ==========================================
# ASYNC GCS UPLOADER (background thread)
# ==========================================
class AsyncGCSUploader:
    def __init__(self, bucket):
        self.bucket = bucket
        self.queue = queue.Queue()
        self.uploads = 0
        self.failures = 0
        self._stop = False
        if bucket is not None:
            self.thread = threading.Thread(target=self._worker, daemon=True)
            self.thread.start()
        else:
            self.thread = None

    def _worker(self):
        while not self._stop or not self.queue.empty():
            try:
                local_path, gcs_path = self.queue.get(timeout=1)
                try:
                    blob = self.bucket.blob(gcs_path)
                    blob.upload_from_filename(local_path)
                    self.uploads += 1
                    print(f"  >> Uploaded to gs://{CONFIG['GCS_BUCKET_NAME']}/{gcs_path}")
                except Exception as e:
                    self.failures += 1
                    print(f"  >> GCS upload failed: {e}")
                self.queue.task_done()
            except queue.Empty:
                continue

    def upload(self, local_path, gcs_path):
        if self.bucket is not None:
            self.queue.put((local_path, gcs_path))

    def wait_and_stop(self):
        if self.thread is not None:
            self.queue.join()
            self._stop = True
            self.thread.join(timeout=10)


# ==========================================
# GCS SETUP
# ==========================================
def setup_gcs():
    try:
        from google.cloud import storage
        key_path = CONFIG.get("GCS_KEY_PATH", "/tmp/gcs_service_account.json")
        if not os.path.exists(key_path):
            print(f"  GCS key not found at {key_path}")
            return None
        os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = key_path
        client = storage.Client()
        bucket = client.bucket(CONFIG["GCS_BUCKET_NAME"])
        try:
            next(bucket.list_blobs(max_results=1), None)
            print(f"  GCS connected: gs://{CONFIG['GCS_BUCKET_NAME']}")
        except Exception:
            print("  WARNING: Could not verify bucket.")
        return bucket
    except Exception as e:
        print(f"  ERROR setting up GCS: {e}")
        return None


# ==========================================
# GPU OPTIMIZATION (Dual T4 + OptiX)
# ==========================================
def force_multi_gpu():
    scene = bpy.context.scene
    scene.render.engine = 'CYCLES'
    scene.cycles.device = 'GPU'
    prefs = bpy.context.preferences.addons['cycles'].preferences

    try:
        prefs.compute_device_type = 'OPTIX'
    except TypeError:
        prefs.compute_device_type = 'CUDA'

    prefs.get_devices()
    for device in prefs.devices:
        if device.type in ['OPTIX', 'CUDA']:
            device.use = True
            print(f"  GPU enabled: {device.name}")
        else:
            device.use = False

    # OptiX Denoiser (GPU-based, replaces CPU CompositorNodeDenoise)
    scene.cycles.use_denoising = True
    try:
        scene.cycles.denoiser = 'OPTIX'
    except Exception:
        try:
            scene.cycles.denoiser = 'OPENIMAGEDENOISE'
        except Exception:
            pass

    scene.render.use_persistent_data = True

    try: scene.render.compositor_device = 'GPU'
    except Exception: pass
    try: scene.cycles.tile_size = 256
    except Exception: pass
    try: scene.cycles.use_fast_gi = True
    except Exception: pass


# ==========================================
# RENDER SINGLE PLY (Ceramic Pipeline)
# ==========================================
def render_single(CFG, meshPath, outputPath):
    """readMesh -> smooth shade -> subdivision -> ceramic material
       -> disconnect Mix Shader Fac/Glossy -> simplified compositor -> render"""

    bt.blenderInit(CFG["IMG_RES_X"], CFG["IMG_RES_Y"], CFG["NUM_SAMPLES"], CFG["EXPOSURE"])
    force_multi_gpu()

    mesh = bt.readMesh(meshPath, CFG["OBJ_LOCATION"], CFG["OBJ_ROTATION"], CFG["OBJ_SCALE"])

    bpy.ops.object.shade_smooth()
    bt.subdivision(mesh, level=CFG["SUBDIVISION_LEVEL"])

    meshC = bt.colorObj(bt.derekBlue, 0.5, 1.0, 1.0, 0.0, 0.0)
    subC = bt.colorObj(bt.derekBlue, 0.5, 2.0, 1.0, 0.0, 1.0)
    bt.setMat_ceramic(mesh, meshC, subC)

    # Disconnect Fac and Glossy BSDF from final Mix Shader
    mat = bpy.context.object.active_material
    nodes = mat.node_tree.nodes
    links = mat.node_tree.links

    mix_shader = next(
        (n for n in nodes if n.type == 'MIX_SHADER'
         and any(o.is_linked and o.links[0].to_node.type == 'OUTPUT_MATERIAL'
                 for o in n.outputs)),
        None
    )
    if mix_shader:
        if mix_shader.inputs['Fac'].is_linked:
            for link in mix_shader.inputs['Fac'].links:
                links.remove(link)
        if mix_shader.inputs[2].is_linked:
            for link in mix_shader.inputs[2].links:
                links.remove(link)
        print("  Disconnected Fac and Glossy BSDF from final Mix Shader.")

    cam = bt.setCamera(CFG["CAM_LOCATION"], CFG["LOOK_AT"], CFG["FOCAL_LENGTH"])
    sun = bt.setLight_sun(CFG["LIGHT_ANGLE"], CFG["LIGHT_STRENGTH"], CFG["SHADOW_SOFTNESS"])
    bt.setLight_ambient(color=CFG["AMBIENT_COLOR"])
    bt.shadowThreshold(alphaThreshold=CFG["SHADOW_THRESHOLD"], interpolationMode='CARDINAL')

    # Simplified compositor (OptiX handles denoising on GPU)
    bpy.context.scene.use_nodes = True
    tree = bpy.context.scene.node_tree
    tree.nodes.clear()
    rl = tree.nodes.new('CompositorNodeRLayers')
    co = tree.nodes.new('CompositorNodeComposite')
    vw = tree.nodes.new('CompositorNodeViewer')
    rl.location = (-300, 0)
    co.location = (300, 0)
    vw.location = (300, -200)
    tree.links.new(rl.outputs['Image'], co.inputs['Image'])
    tree.links.new(rl.outputs['Image'], vw.inputs['Image'])

    if CFG["SAVE_BLEND_FILE"]:
        bp = outputPath.replace(".png", ".blend")
        bpy.ops.wm.save_mainfile(filepath=bp)

    bt.renderImage(outputPath, cam)


# ==========================================
# MAIN
# ==========================================
def render_all_ply():
    C = CONFIG
    print(f"\n{'='*60}")
    print(f"  RENDERING PLY: {C['PC_TYPE']} (Kaggle Dual T4)")
    print(f"{'='*60}\n")

    local_dir = C["LOCAL_INPUT_DIR"]
    output_dir = os.path.join(C["KAGGLE_OUTPUT_DIR"], "plyFormat", C["PC_TYPE"])
    os.makedirs(output_dir, exist_ok=True)

    if not os.path.exists(local_dir):
        print(f"ERROR: Input directory not found: {local_dir}")
        return

    ply_files = sorted([f for f in os.listdir(local_dir) if f.endswith('.ply')])
    total = len(ply_files)
    print(f"Found {total} .ply files to render.\n")

    print("--- Setting up Google Cloud Storage ---")
    gcs_bucket = setup_gcs()
    uploader = AsyncGCSUploader(gcs_bucket)

    wandb.init(project="pyblender-render-farm", name=f"PLY_{C['PC_TYPE']}", config=C)

    completed = 0
    for idx, filename in enumerate(ply_files, 1):
        meshPath = os.path.join(local_dir, filename)
        out_name = filename.replace(".ply", ".png")
        outputPath = os.path.join(output_dir, out_name)
        gcs_blob_path = f"{C['GCS_BASE_PATH']}/{C['PC_TYPE']}/{out_name}"

        # Check GCS for existing render
        if gcs_bucket and not C["FORCE_OVERWRITE"]:
            blob = gcs_bucket.blob(gcs_blob_path)
            if blob.exists():
                print(f"[{idx}/{total}] Already on GCS: {out_name}. Skipping...")
                completed += 1
                continue

        # Check local
        if os.path.exists(outputPath) and not C["FORCE_OVERWRITE"]:
            print(f"[{idx}/{total}] Exists locally: {out_name}. Skipping...")
            completed += 1
            continue

        start_time = time.time()
        print(f"[{idx}/{total}] Rendering [{filename}]...")
        render_single(C, meshPath, outputPath)

        uploader.upload(outputPath, gcs_blob_path)

        duration = time.time() - start_time
        completed += 1
        pct = (completed / total) * 100

        wandb.log({
            "progress_percent": pct,
            "render_time_seconds": duration,
            "filename": filename,
            "gcs_uploads_total": uploader.uploads,
            "latest_render": wandb.Image(outputPath),
        })
        print(f"[{idx}/{total}] Done: {filename} in {duration:.1f}s [{pct:.0f}%]\n")

    print("\n--- Waiting for remaining GCS uploads ---")
    uploader.wait_and_stop()

    print(f"\n{'='*50}")
    print(f"  RENDER COMPLETE!")
    print(f"  Total: {completed}/{total}")
    print(f"  GCS uploads: {uploader.uploads} (failures: {uploader.failures})")
    print(f"  Bucket: gs://{C['GCS_BUCKET_NAME']}/{C['GCS_BASE_PATH']}/{C['PC_TYPE']}/")
    print(f"{'='*50}\n")
    wandb.finish()


if __name__ == "__main__":
    render_all_ply()

# %%
#@title 6. Start Rendering

# !./blender-4.0.2-linux-x64/blender -b -P render_ply.py

# %%
#@title 7. Upload remaining local renders to GCS
import os
from google.cloud import storage

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/tmp/gcs_service_account.json"
client = storage.Client()
bucket = client.bucket("pyblender-render-farm")

local_base = "/kaggle/working/RenderImages/plyFormat"
gcs_base = "RenderImages/plyFormat"
uploaded = 0

for root, dirs, files in os.walk(local_base):
    for f in files:
        if f.endswith(".png"):
            local_path = os.path.join(root, f)
            relative = os.path.relpath(local_path, local_base)
            gcs_path = f"{gcs_base}/{relative}"
            blob = bucket.blob(gcs_path)
            if not blob.exists():
                blob.upload_from_filename(local_path)
                uploaded += 1
                print(f"  Uploaded: {gcs_path}")

print(f"\nDone! Uploaded {uploaded} files.")
